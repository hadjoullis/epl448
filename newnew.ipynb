# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
from scipy.stats import shapiro, anderson, kstest, normaltest, jarque_bera, normaltest, boxcox, yeojohnson
from statsmodels.stats.diagnostic import lilliefors
from rapidfuzz import process, fuzz
from collections import defaultdict

# %%
df = pd.read_csv("dataset/autos.csv")

# %%
df.head()
# Out:
#    index          dateCrawled                            name  seller  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6  privat
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat
#
#   offerType  price abtest vehicleType  yearOfRegistration    gearbox  ...  \
# 0   Angebot    480   test         NaN                1993    manuell  ...
# 1   Angebot  18300   test       coupe                2011    manuell  ...
# 2   Angebot   9800   test         suv                2004  automatik  ...
# 3   Angebot   1500   test  kleinwagen                2001    manuell  ...
# 4   Angebot   3600   test  kleinwagen                2008    manuell  ...
#
#    model kilometer  monthOfRegistration  fuelType       brand  \
# 0   golf    150000                    0    benzin  volkswagen
# 1    NaN    125000                    5    diesel        audi
# 2  grand    125000                    8    diesel        jeep
# 3   golf    150000                    6    benzin  volkswagen
# 4  fabia     90000                    7    diesel       skoda
#
#   notRepairedDamage          dateCreated nrOfPictures  postalCode  \
# 0               NaN  2016-03-24 00:00:00            0       70435
# 1                ja  2016-03-24 00:00:00            0       66954
# 2               NaN  2016-03-14 00:00:00            0       90480
# 3              nein  2016-03-17 00:00:00            0       91074
# 4              nein  2016-03-31 00:00:00            0       60437
#
#               lastSeen
# 0  2016-04-07 03:16:57
# 1  2016-04-07 01:46:50
# 2  2016-04-05 12:47:46
# 3  2016-03-17 17:40:17
# 4  2016-04-06 10:17:21
#
# [5 rows x 21 columns]

# %%
print("Dataset")
df.shape
# Out:
# Dataset
# (371528, 21)

# %%
print("Dataset")
df.dtypes
# Out:
# Dataset
# index                   int64
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                   int64
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# kilometer               int64
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# nrOfPictures            int64
# postalCode              int64
# lastSeen               object
# dtype: object

# %%
missing_values = df.isnull().sum()
print("Missing Values per Column:")
missing_values
# Out:
# Missing Values per Column:
# index                      0
# dateCrawled                0
# name                       0
# seller                     0
# offerType                  0
# price                      0
# abtest                     0
# vehicleType            37869
# yearOfRegistration         0
# gearbox                20209
# powerPS                    0
# model                  20484
# kilometer                  0
# monthOfRegistration        0
# fuelType               33386
# brand                      0
# notRepairedDamage      72060
# dateCreated                0
# nrOfPictures               0
# postalCode                 0
# lastSeen                   0
# dtype: int64

# %%
print("Summary Statistics:")
df.describe()
# Out:
# Summary Statistics:
#                index         price  yearOfRegistration        powerPS  \
# count  371528.000000  3.715280e+05       371528.000000  371528.000000
# mean   185763.500000  1.729514e+04         2004.577997     115.549477
# std    107251.039743  3.587954e+06           92.866598     192.139578
# min         0.000000  0.000000e+00         1000.000000       0.000000
# 25%     92881.750000  1.150000e+03         1999.000000      70.000000
# 50%    185763.500000  2.950000e+03         2003.000000     105.000000
# 75%    278645.250000  7.200000e+03         2008.000000     150.000000
# max    371527.000000  2.147484e+09         9999.000000   20000.000000
#
#            kilometer  monthOfRegistration  nrOfPictures    postalCode
# count  371528.000000        371528.000000      371528.0  371528.00000
# mean   125618.688228             5.734445           0.0   50820.66764
# std     40112.337051             3.712412           0.0   25799.08247
# min      5000.000000             0.000000           0.0    1067.00000
# 25%    125000.000000             3.000000           0.0   30459.00000
# 50%    150000.000000             6.000000           0.0   49610.00000
# 75%    150000.000000             9.000000           0.0   71546.00000
# max    150000.000000            12.000000           0.0   99998.00000

# %%
# Count of unique values in offerType
df.groupby('offerType').count()
# Out:
#             index  dateCrawled    name  seller   price  abtest  vehicleType  \
# offerType
# Angebot    371516       371516  371516  371516  371516  371516       333654
# Gesuch         12           12      12      12      12      12            5
#
#            yearOfRegistration  gearbox  powerPS   model  kilometer  \
# offerType
# Angebot                371516   351313   371516  351035     371516
# Gesuch                     12        6       12       9         12
#
#            monthOfRegistration  fuelType   brand  notRepairedDamage  \
# offerType
# Angebot                 371516    338137  371516             299462
# Gesuch                      12         5      12                  6
#
#            dateCreated  nrOfPictures  postalCode  lastSeen
# offerType
# Angebot         371516        371516      371516    371516
# Gesuch              12            12          12        12

# %%
# Count of unique values in seller
df.groupby('seller').count()
# Out:
#              index  dateCrawled    name  offerType   price  abtest  \
# seller
# gewerblich       3            3       3          3       3       3
# privat      371525       371525  371525     371525  371525  371525
#
#             vehicleType  yearOfRegistration  gearbox  powerPS   model  \
# seller
# gewerblich            3                   3        3        3       3
# privat           333656              371525   351316   371525  351041
#
#             kilometer  monthOfRegistration  fuelType   brand  \
# seller
# gewerblich          3                    3         3       3
# privat         371525               371525    338139  371525
#
#             notRepairedDamage  dateCreated  nrOfPictures  postalCode  lastSeen
# seller
# gewerblich                  2            3             3           3         3
# privat                 299466       371525        371525      371525    371525

# %%
# Count of unique values in nrOfPictures
df.groupby('nrOfPictures').count()
# Out:
#                index  dateCrawled    name  seller  offerType   price  abtest  \
# nrOfPictures
# 0             371528       371528  371528  371528     371528  371528  371528
#
#               vehicleType  yearOfRegistration  gearbox  powerPS   model  \
# nrOfPictures
# 0                  333659              371528   351319   371528  351044
#
#               kilometer  monthOfRegistration  fuelType   brand  \
# nrOfPictures
# 0                371528               371528    338142  371528
#
#               notRepairedDamage  dateCreated  postalCode  lastSeen
# nrOfPictures
# 0                        299468       371528      371528    371528

# %% [markdown]
# #### Irrelevant parameters
# * offerType
# * seller
# * nrOfPictures
#
# For each param one value dominates. Since each column has essentially one value, it is irrelevant as a param

# %%
# First remove the few rows affected
df = df.drop(df[(df['offerType'] == 'Gesuch') | (df['seller'] == 'gewerblich')].index, axis='index')

# Now remove the irrelevant columns
df = df.drop(['offerType', 'seller', 'nrOfPictures'], axis='columns')
df.dtypes
# Out:
# index                   int64
# dateCrawled            object
# name                   object
# price                   int64
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# kilometer               int64
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# postalCode              int64
# lastSeen               object
# dtype: object

# %%
df.shape
# Out:
# (371513, 18)

# %%
df.head()
# Out:
#    index          dateCrawled                            name  price abtest  \
# 0      0  2016-03-24 11:52:17                      Golf_3_1.6    480   test
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  18300   test
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"   9800   test
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER   1500   test
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic   3600   test
#
#   vehicleType  yearOfRegistration    gearbox  powerPS  model  kilometer  \
# 0         NaN                1993    manuell        0   golf     150000
# 1       coupe                2011    manuell      190    NaN     125000
# 2         suv                2004  automatik      163  grand     125000
# 3  kleinwagen                2001    manuell       75   golf     150000
# 4  kleinwagen                2008    manuell       69  fabia      90000
#
#    monthOfRegistration fuelType       brand notRepairedDamage  \
# 0                    0   benzin  volkswagen               NaN
# 1                    5   diesel        audi                ja
# 2                    8   diesel        jeep               NaN
# 3                    6   benzin  volkswagen              nein
# 4                    7   diesel       skoda              nein
#
#            dateCreated  postalCode             lastSeen
# 0  2016-03-24 00:00:00       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00       60437  2016-04-06 10:17:21

# %%
def clean_text(text):
    if not isinstance(text, str):
        return ""
    # Lowercase, remove non-alphanumeric characters, collapse whitespace
    return re.sub(r'\s+', ' ', re.sub(r'[^a-z0-9]', ' ', text.lower())).strip()

def fuzzy_match_model(name, known_models, threshold=50):
    """
    Fuzzy match `name` against a list/array of known models.
    Returns the best candidate if the score meets the threshold; else, returns None.
    """
    scored = [(model, fuzz.token_set_ratio(name, model)) for model in known_models]
    best_match, best_score = max(scored, key=lambda x: x[1])
    return best_match if best_score >= threshold else None

def match_model(row):
    if pd.isnull(row['model']):
        brand = clean_text(row.get('brand'))
        name = clean_text(row.get('name'))
        candidates = brand_model_map.get(brand)
        if candidates is None or len(candidates) == 0:
            return None
        return fuzzy_match_model(name, candidates)
    return row['model']  # leave as-is if already filled

# %%
brand_model_df = pd.read_csv("dataset/all-brand-models.csv")
brand_model_df
# Out:
#        brand      model
# 0      acura         cl
# 1      acura        csx
# 2      acura         el
# 3      acura        ilx
# 4      acura    integra
# ...      ...        ...
# 6342  yamaha    yzf600r
# 6343  yamaha     yzf-r1
# 6344  yamaha  yzf-r1 le
# 6345  yamaha     yzf-r6
# 6346  yamaha    yzf-r6s
#
# [6347 rows x 2 columns]

# %%
# Build the brand -> list of models mapping
brand_model_map = defaultdict(list)

for _, row in brand_model_df.iterrows():
    brand = clean_text(row['brand'])
    model = clean_text(row['model'])
    brand_model_map[brand].append(model)

brand_model_map = dict(brand_model_map)
# convert into numpy array to use fuzzy search later
for brand in brand_model_map:
    brand_model_map[brand] = np.array(sorted(brand_model_map[brand]))
brand_model_map
# Out:
# {'acura': array(['cl', 'csx', 'el', 'ilx', 'integra', 'legend', 'mdx',
#         'mdx sport hybrid', 'nsx', 'rdx', 'rl', 'rlx', 'rlx sport hybrid',
#         'rsx', 'slx', 'tl', 'tlx', 'tsx', 'vigor', 'zdx'], dtype='<U16'),
#  'alfa romeo': array(['147', '156', '159', '164', '4c', '4c spider', '8c', 'brera',
#         'giulia', 'giulietta', 'gt', 'mito', 'spider', 'stelvio', 'tonale'],
#        dtype='<U9'),
#  'american ironhorse': array(['bandera', 'classic', 'classic chop', 'judge', 'legend', 'lsc',
#         'outlaw', 'ranger', 'ranger t', 'slammer', 'stalker', 'tejas',
#         'texas chopper', 'thunder'], dtype='<U13'),
#  'american lafrance': array(['alf eagle', 'condor'], dtype='<U9'),
#  'am general': array(['hummer'], dtype='<U6'),
#  'aprilia': array(['atlantic 500', 'caponord 1200', 'dorsoduro 1200', 'dorsoduro 750',
#         'dorsoduro 750 abs', 'etv 1000 caponord', 'mana 850',
#         'mana 850 gt abs', 'mojito 150', 'mojito custom 50',
#         'mojito retro 50', 'pegaso 650', 'pegaso 650 factory',
#         'pegaso 650 trail', 'rally 50 air cooled', 'rs 125', 'rs 250',
#         'rs 50', 'rst1000 futura', 'rsv 1000 r', 'rsv 1000 r factory',
#         'rsv mille', 'rsv mille r', 'rsv mille r haga', 'rsv mille r nera',
#         'rsv4 factory', 'rsv4 factory aprc abs', 'rsv4 factory se',
#         'rsv4 r', 'rsv4 r aprc abs', 'rxv 450', 'rxv 550', 'scarabeo 100',
#         'scarabeo 125', 'scarabeo 150', 'scarabeo 200', 'scarabeo 250',
#         'scarabeo 50 2t', 'scarabeo 50 4t', 'scarabeo 50 ditech',
#         'scarabeo 500 ie', 'shiver 750', 'sl 750 shiver', 'sl1000 falco',
#         'smv 750 dorsoduro', 'sportcity 125', 'sportcity 250',
#         'sportcity 50', 'sportcity cube 250', 'sr 50', 'sr 50 ditech',
#         'sr 50 r replica sbk', 'sr motard 50', 'sr50r factory', 'sxv 450',
#         'sxv 550', 'tuono 1000 r', 'tuono 1000 r factory', 'tuono 125',
#         'tuono 50', 'tuono fighter 1000', 'tuono racer 1000', 'tuono v4 r',
#         'tuono v4 r aprc'], dtype='<U21'),
#  'arctic cat': array(['1000 efi h2 4x4 auto mud pro', '1000 efi h2 4x4 auto trv',
#         '1000 ltd', '1000 trv cruiser', '1000 xt', '1000i gt', '150 2x4',
#         '250 2x4', '250 4x4', '300', '300 2x4', '300 2x4 auto', '300 4x4',
#         '300 4x4 mrp', '350', '366 4x4 auto', '366 4x4 auto se',
#         '375 auto 2x4', '375 auto 4x4', '4 stroke touring',
#         '4 stroke trail', '400', '400 2x4', '400 2x4 auto', '400 2x4 fis',
#         '400 4x4', '400 4x4 act', '400 4x4 auto', '400 4x4 auto act',
#         '400 4x4 auto le', '400 4x4 auto mrp', '400 4x4 auto tbx',
#         '400 4x4 auto trv', '400 4x4 auto trv plus', '400 4x4 auto vp',
#         '400 4x4 fis', '400 4x4 mrp', '400 4x4 vp', '400 core', '425',
#         '425i', '425i se', '450', '450 core', '450 efi h1 4x4 auto',
#         '450 ltd', '450 trv', '450i', '450i gt', '50 2x4', '500 4x4',
#         '500 4x4 auto', '500 4x4 auto fis', '500 4x4 auto le',
#         '500 4x4 auto m4', '500 4x4 auto mrp', '500 4x4 auto tbx',
#         '500 4x4 auto trv', '500 4x4 fis', '500 4x4 mrp', '500 core',
#         '500 xt', '550', '550 4x4 auto', '550 4x4 auto le',
#         '550 4x4 auto trv', '550 4x4 auto trv le', '550 core',
#         '550 h1 efi', '550 ltd', '550 s', '550 trv cruiser', '550 trv gt',
#         '550 xt', '550i gt', '550i ltd', '650 4x4 auto', '650 4x4 auto le',
#         '650 4x4 auto tbx', '650 h1 4x4 auto', '650 h1 4x4 auto le',
#         '650 h1 4x4 auto mud pro', '650 h1 4x4 auto se',
#         '650 h1 4x4 auto tbx', '650 h1 4x4 auto trv',
#         '650 h1 4x4 auto trv plus', '650 h1 4x4 auto trv plus le',
#         '650 v 2 4x4 auto', '650 v 2 4x4 auto le ts',
#         '650 v 2 4x4 auto mrp', '700', '700 core', '700 diesel',
#         '700 efi 4x4 auto', '700 efi 4x4 auto le', '700 efi 4x4 auto m4',
#         '700 efi 4x4 auto se', '700 efi 4x4 auto trv cruiser',
#         '700 efi 4x4 auto trv le', '700 efi h1 4x4 auto',
#         '700 efi h1 4x4 auto le', '700 efi h1 4x4 auto mud pro',
#         '700 efi h1 4x4 auto se', '700 efi h1 4x4 auto tbx',
#         '700 efi h1 4x4 auto trv', '700 ltd', '700 s',
#         '700 super duty diesel', '700 trv gt', '700 xt', '700i', '700i gt',
#         '700i ltd', '90 2x4', '90 2x4 4 stroke', '90 2x4 se',
#         'ac 120 sno pro', 'ac 440 sno pro', 'ac 440 sno pro modified',
#         'ac 600 sno pro', 'bearcat 2000 lt', 'bearcat 2000 xt',
#         'bearcat 2000 xte', 'bearcat 5000 xt', 'bearcat 5000 xt gs',
#         'bearcat 5000 xt limited', 'bearcat 570', 'bearcat 570 long track',
#         'bearcat 570 xt', 'bearcat widetrack', 'bearcat widetrack turbo',
#         'bearcat widetrack turbo articulatin', 'bearcat z1 xt',
#         'bearcat z1 xt gs', 'bearcat z1 xt limited', 'cfr 1000', 'cfr 8',
#         'crossfire 1000 efi', 'crossfire 1000 efi sno pro',
#         'crossfire 1000 sno pro le', 'crossfire 500 efi',
#         'crossfire 600 efi', 'crossfire 600 efi sno pro',
#         'crossfire 700 efi', 'crossfire 700 efi early build',
#         'crossfire 700 efi sno pro', 'crossfire 8', 'crossfire 800 efi',
#         'crossfire 800 efi limited', 'crossfire 800 efi sno pro',
#         'crossfire 800 efi sno pro le', 'crossfire r 1000',
#         'crossfire r 1000 le', 'crossfire r 8', 'crossfire r 8 le',
#         'dvx 250', 'dvx 300', 'dvx 400', 'dvx 400 ts', 'dvx 50', 'dvx 90',
#         'dvx 90 se', 'f1000 efi', 'f1000 efi lxr', 'f1000 efi sno pro',
#         'f120', 'f5', 'f5 efi', 'f5 efi lxr', 'f5 lxr', 'f570', 'f6 efi',
#         'f6 efi lxr', 'f6 efi sno pro', 'f8 efi', 'f8 efi lxr',
#         'f8 efi lxr le', 'f8 efi sno pro', 'f8 efi sno pro tony stewart',
#         'f8 ext', 'f8 sno pro limited', 'firecat 500',
#         'firecat 500 sno pro', 'firecat 600', 'firecat 600 efi',
#         'firecat 600 efi early build', 'firecat 600 efi ext',
#         'firecat 600 efi r', 'firecat 600 efi sno pro',
#         'firecat 600 sno pro', 'firecat 700', 'firecat 700 efi',
#         'firecat 700 efi ext', 'firecat 700 efi r',
#         'firecat 700 efi sno pro', 'firecat 700 efi tony stewart',
#         'firecat 700 sno pro', 'jaguar z1 1100 efi',
#         'jaguar z1 1100 efi sno pro', 'jaguar z1 early build',
#         'king cat 900', 'king cat 900 efi', 'king cat 900 efi early build',
#         'lynx 2000', 'lynx 2000 lt', 'm 6000 153', 'm 6000 sno pro 153',
#         'm 8000 153', 'm 8000 david mcclure se', 'm 8000 hcr 153',
#         'm 8000 limited 153', 'm 8000 limited 162',
#         'm 8000 limited es 153', 'm 8000 limited es 162',
#         'm 8000 rob kincaid se', 'm 8000 sno pro 153',
#         'm 8000 sno pro 162', 'm 9000 153', 'm 9000 hcr 162',
#         'm 9000 limited 162', 'm 9000 sno pro 162', 'm1000 efi 153',
#         'm1000 efi 153 sno pro', 'm1000 efi 162', 'm1000 efi 162 sno pro',
#         'm1000 efi 162 sno pro le', 'm5', 'm6 efi 141', 'm6 efi 153',
#         'm7 153', 'm7 efi 141', 'm7 efi 153', 'm7 efi 162', 'm7 efi le',
#         'm7 efi le 153', 'm7 efi le 162', 'm8 153', 'm8 153 limited',
#         'm8 153 sno pro le', 'm8 162', 'm8 efi 141', 'm8 efi 153',
#         'm8 efi 153 sno pro', 'm8 efi 153 sno pro le', 'm8 efi 162',
#         'm8 efi 162 sno pro', 'm8 hcr 153', 'm8 sno pro 153',
#         'm8 sno pro 162', 'mountain cat 1000', 'mountain cat 500',
#         'mountain cat 500 efi', 'mountain cat 570', 'mountain cat 600 efi',
#         'mountain cat 600 efi 136', 'mountain cat 600 efi 144',
#         'mountain cat 600 efi le', 'mountain cat 600 vev',
#         'mountain cat 800', 'mountain cat 800 efi',
#         'mountain cat 800 efi 144', 'mountain cat 800 efi 151',
#         'mountain cat 800 efi 159', 'mountain cat 800 efi le 144',
#         'mountain cat 800 efi le 151', 'mountain cat 800 le',
#         'mountain cat 800 le 144', 'mountain cat 800 le 151',
#         'mountain cat 900 144', 'mountain cat 900 151',
#         'mountain cat 900 159', 'mountain cat 900 1m',
#         'mountain cat 900 early build', 'mountain cat 900 efi 151',
#         'mountain cat 900 efi 159', 'mudpro 1000', 'mudpro 1000i ltd',
#         'mudpro 650', 'mudpro 700', 'mudpro 700i', 'mudpro 700i ltd',
#         'pantera 1000', 'pantera 550', 'pantera 580 efi',
#         'pantera 600 efi', 'pantera 600 efi esr', 'pantera 800 efi',
#         'pantera 800 efi esr', 'panther 370', 'panther 370 r',
#         'panther 440', 'panther 440 esr', 'panther 550', 'panther 570',
#         'panther 570 esr', 'panther 570 r', 'panther 660 touring',
#         'panther 660 trail', 'proclimb m 1100', 'proclimb m 1100 sno pro',
#         'proclimb m 1100 sno pro 50th', 'proclimb m 1100 sno pro limited',
#         'proclimb m 1100 turbo', 'proclimb m 1100 turbo hcr',
#         'proclimb m 1100 turbo sno pro',
#         'proclimb m 1100 turbo sno pro 50th',
#         'proclimb m 1100 turbo sno pro limit', 'proclimb m 800',
#         'proclimb m 800 hcr', 'proclimb m 800 sno pro 153',
#         'proclimb m 800 sno pro 162', 'proclimb m 800 sno pro limited 153',
#         'proclimb m 800 sno pro limited 162',
#         'proclimb xf 1100 turbo sno pro high',
#         'proclimb xf 800 sno pro high countr', 'procross f 1100 lxr',
#         'procross f 1100 sno pro', 'procross f 1100 sno pro 50th',
#         'procross f 1100 sno pro limited', 'procross f 1100 turbo lxr',
#         'procross f 1100 turbo sno pro',
#         'procross f 1100 turbo sno pro 50th',
#         'procross f 1100 turbo sno pro limit',
#         'procross f 1100 turbo sno pro rr', 'procross f 800 lxr',
#         'procross f 800 sno pro', 'procross f 800 sno pro limited',
#         'procross f 800 sno pro rr', 'procross f 800 tucker hibbert race',
#         'procross xf 1100 crosstour', 'procross xf 1100 lxr',
#         'procross xf 1100 sno pro', 'procross xf 1100 sno pro 50th',
#         'procross xf 1100 sno pro limited',
#         'procross xf 1100 turbo crosstour', 'procross xf 1100 turbo lxr',
#         'procross xf 1100 turbo sno pro',
#         'procross xf 1100 turbo sno pro 50th',
#         'procross xf 1100 turbo sno pro limi', 'procross xf 800 crosstour',
#         'procross xf 800 lxr', 'procross xf 800 sno pro',
#         'procross xf 800 sno pro limited', 'prowler 550',
#         'prowler 650 4x4 auto', 'prowler 650 h1', 'prowler hdx 500',
#         'prowler hdx 500 limited', 'prowler hdx 500 xt', 'prowler hdx 700',
#         'prowler hdx 700 limited', 'prowler hdx 700i', 'prowler xt 550',
#         'prowler xt 550i', 'prowler xt 650 4x4 auto',
#         'prowler xt 650 4x4 auto m4', 'prowler xt 650 h1',
#         'prowler xt 700', 'prowler xtx 700', 'prowler xtx 700 h1 efi',
#         'prowler xtx 700 le', 'prowler xtx 700i', 'prowler xtz 1000',
#         'prowler xtz 1000 baja', 'prowler xtz 1000 h2 efi',
#         'prowler xtz 1000i', 'sabercat 500', 'sabercat 500 efi',
#         'sabercat 500 efi lx', 'sabercat 500 lx', 'sabercat 600',
#         'sabercat 600 efi', 'sabercat 600 efi ext', 'sabercat 600 efi lx',
#         'sabercat 600 lx', 'sabercat 700 efi', 'sabercat 700 efi ext',
#         'sabercat 700 efi lx', 'sbs 1000', 'sno pro 120', 'sno pro 500',
#         't500', 't570', 't660 touring', 't660 turbo', 't660 turbo st',
#         't660 turbo st efi early build', 't660 turbo touring',
#         't660 turbo touring le', 't660 turbo trail', 't660 turbo trail le',
#         'tbx 700', 'tbx 700 ltd', 'tbx 700 xt', 'tbx 700i gt',
#         'thundercat', 'thundercat 1000 4x4 auto',
#         'thundercat 1000 4x4 auto le', 'triple touring', 'trv 1000 ltd',
#         'trv 1000i cruiser', 'trv 1000i gt', 'trv 400', 'trv 400 core',
#         'trv 450i', 'trv 450i gt', 'trv 500 core', 'trv 550 ltd',
#         'trv 550 xt', 'trv 550i crusier', 'trv 550i gt', 'trv 700 ltd',
#         'trv 700 xt', 'trv 700i cruiser', 'trv 700i gt', 'tz1', 'tz1 lxr',
#         'tz1 park', 'tz1 touring', 'tz1 touring lxr', 'tz1 turbo lxr',
#         'tz1 turbo lxr le', 'tz1 turbo touring lxr', 'wildcat 1000',
#         'wildcat 1000 ltd', 'wildcat 4 1000', 'wildcat 4 limited',
#         'wildcat 4x', 'wildcat 4x limited', 'wildcat trail',
#         'wildcat trail xt', 'wildcat x 1000', 'wildcat x limited',
#         'xc 450i', 'xf 6000 cross country', 'xf 6000 crosstour',
#         'xf 6000 high country', 'xf 6000 limited', 'xf 6000 lxr',
#         'xf 6000 sno pro', 'xf 7000 cross country sno pro',
#         'xf 7000 crosstour', 'xf 7000 limited', 'xf 7000 lxr',
#         'xf 7000 sno pro', 'xf 8000 cross country',
#         'xf 8000 cross country limited', 'xf 8000 cross country sno pro',
#         'xf 8000 crosstour', 'xf 8000 high country',
#         'xf 8000 high country limited', 'xf 8000 high country sno pro',
#         'xf 8000 limited', 'xf 8000 lxr', 'xf 8000 sno pro',
#         'xf 9000 cross country', 'xf 9000 cross country limited',
#         'xf 9000 cross country sno pro', 'xf 9000 crosstour',
#         'xf 9000 high country', 'xf 9000 high country limited',
#         'xf 9000 high country sno pro', 'xf 9000 limited', 'xf 9000 lxr',
#         'xf 9000 sno pro', 'z 120', 'z 120 sno pro', 'z 370', 'z 370 es',
#         'z 370 esr', 'z 370 lx', 'z 440', 'z 440 es', 'z 440 esr',
#         'z 440 lx', 'z 440 sno pro', 'z 570', 'z 570 esr', 'z 570 lx',
#         'z 570 ss', 'z1 1100 efi', 'z1 1100 efi lxr', 'z1 sno pro',
#         'z1 turbo', 'z1 turbo ext', 'z1 turbo ext limited', 'z1 turbo lxr',
#         'z1 turbo lxr le', 'z1 turbo sno pro', 'z1 turbo sno pro limited',
#         'zl 500', 'zl 500 efi esr', 'zl 550', 'zl 550 esr', 'zl 600 efi',
#         'zl 600 efi esr', 'zl 600 efi ss', 'zl 600 efi ss esr',
#         'zl 800 efi esr', 'zl 800 efi ss', 'zl 800 esr', 'zr 120',
#         'zr 4000 lxr', 'zr 4000 rr', 'zr 440 sno pro', 'zr 500',
#         'zr 500 efi', 'zr 500 efi esr', 'zr 500 le', 'zr 5000 lxr',
#         'zr 600', 'zr 600 efi', 'zr 600 efi le', 'zr 600 vev',
#         'zr 6000 el tigre', 'zr 6000 el tigre es', 'zr 6000 limited',
#         'zr 6000 lxr', 'zr 6000 rr', 'zr 6000 sno pro',
#         'zr 6000 tucker hibbert rr', 'zr 7000 limited', 'zr 7000 lxr',
#         'zr 7000 sno pro', 'zr 800', 'zr 800 efi', 'zr 800 efi sno pro',
#         'zr 800 le', 'zr 8000 el tigre', 'zr 8000 limited', 'zr 8000 lxr',
#         'zr 8000 rr', 'zr 8000 sno pro', 'zr 900', 'zr 900 early build',
#         'zr 900 efi', 'zr 900 efi sno pro', 'zr 900 sno pro',
#         'zr 9000 el tigre', 'zr 9000 limited', 'zr 9000 lxr', 'zr 9000 rr',
#         'zr 9000 sno pro', 'zrt 600', 'zrt 600 le', 'zrt 800',
#         'zrt 800 le'], dtype='<U35'),
#  'argo': array(['750 hdi 8x8', '750 hdi 8x8 special edition', '8x8 700 hd',
#         '8x8 750 hdi', '8x8 750 hdi se', '8x8 xti', 'avenger 700 8x8',
#         'avenger 750 efi 8x8', 'bigfoot 6x6', 'conquest 6x6',
#         'conquest 8x8', 'frontier 580 6x6', 'frontier 650 6x6',
#         'frontier 650 8x8', 'frontier 6x6',
#         'jim shockey limited edition signatu', 'response 8x8',
#         'vanguard 2 6x6', 'vanguard 6x6'], dtype='<U35'),
#  'aston martin': array(['db11', 'db7', 'db9', 'db9 gt', 'dbs', 'dbs superleggera', 'dbx',
#         'rapide', 'rapide amr', 'rapide s', 'v12 vantage', 'v12 vantage s',
#         'v8 vantage', 'vanquish', 'vanquish s', 'vantage', 'virage'],
#        dtype='<U16'),
#  'atk': array(['125 cc', '125 enduro', '250 enduro', '260 enduro', '350 enduro',
#         '50 mx', '50 mxlq', '500 dt', '600 dt', '600 mt', '605 enduro'],
#        dtype='<U10'),
#  'audi': array(['100', '80', '90', 'a1', 'a3', 'a3 quattro', 'a3 sportback e tron',
#         'a4', 'a4 2005 5', 'a4 allroad', 'a4 quattro', 'a5', 'a5 quattro',
#         'a5 sport', 'a6', 'a6 allroad', 'a6 quattro', 'a7', 'a7 quattro',
#         'a8', 'a8 quattro', 'allroad', 'allroad quattro', 'cabriolet',
#         'e tron', 'e tron gt', 'e tron s', 'e tron s sportback',
#         'e tron sportback', 'q3', 'q3 quattro', 'q4 e tron',
#         'q4 sportback e tron', 'q5', 'q5 sportback', 'q6 e tron', 'q7',
#         'q8', 'q8 e tron', 'q8 sportback e tron', 'quattro', 'r8', 'rs 3',
#         'rs 4', 'rs 5', 'rs 6', 'rs 7', 'rs e tron gt', 'rs q8', 'rs4',
#         'rs5', 'rs6', 'rs7', 's3', 's4', 's4 2005 5', 's5', 's6', 's7',
#         's8', 'sq5', 'sq5 sportback', 'sq7', 'sq8', 'sq8 e tron',
#         'sq8 sportback e tron', 'tt', 'tt quattro', 'tt rs', 'tts'],
#        dtype='<U20'),
#  'autocar llc': array(['xpeditor', 'xpeditor wx', 'xpeditor wxll', 'xpert'], dtype='<U13'),
#  'avanti': array(['avanti', 'ii'], dtype='<U6'),
#  'bentley': array(['arnage', 'azure', 'azure t', 'bentayga', 'brooklands',
#         'continental', 'continental gt', 'continental gt3 r',
#         'flying spur', 'mulsanne'], dtype='<U17'),
#  'bertone': array(['x 1 9'], dtype='<U5'),
#  'beta': array(['400 rr', '450 rr', '450 rs', '525 rr', '525 rs'], dtype='<U6'),
#  'big dog': array(['boxer', 'bulldog', 'bulldog sport', 'chopper', 'chopper bdm',
#         'chopper dt', 'chopper rt', 'coyote', 'husky', 'k 9', 'k 9 250',
#         'k 9 efi', 'mastiff', 'mastiff efi', 'mutt', 'pitbull',
#         'pro sport', 'ridgeback', 'vintage sport', 'wolf'], dtype='<U13'),
#  'bimota': array(['sb8r'], dtype='<U4'),
#  'blue bird': array(['all american', 'bb conventional', 'shl all american',
#         'shl tc2000', 'tc2000', 'wanderlodge'], dtype='<U16'),
#  'bmw': array(['1 series', '1 series m', '114d', '114i', '116d', '116i', '118d',
#         '118i', '120d', '120d xdrive', '120i', '123d', '123i', '125d',
#         '125i', '128i', '128ti', '130i', '135i', '135is', '2 series',
#         '2 series gran coupe', '218d', '218i', '220d', '220i', '225d',
#         '228i', '228i xdrive', '230i', '235i', '3 series', '3 series e36',
#         '3 series gran turismo', '316', '316d', '316i', '318', '318d',
#         '318i', '318tds', '320', '320d', '320i', '320i xdrive', '323i',
#         '324d', '324td', '325ci', '325d', '325i', '325td', '325tds',
#         '325xi', '328d', '328d xdrive', '328i', '328i gt xdrive',
#         '328i xdrive', '328xi', '330ci', '330d', '330e plug in hybrid',
#         '330i', '330xi', '335d', '335i', '335i gt xdrive', '335i xdrive',
#         '335is', '335xi', '340i', '4 series', '4 series gran coupe',
#         '420d', '420i', '425d', '428i', '428i gran coupe', '428i xdrive',
#         '428i xdrive gran coupe', '430d', '430i', '435d', '435i',
#         '435i gran coupe', '435i xdrive', '435i xdrive gran coupe', '440i',
#         '5 series', '5 series gran turismo', '518', '518i', '520', '520i',
#         '523i', '524d', '524td', '525', '525i', '525td', '525tds', '525xi',
#         '528', '528i', '528i xdrive', '528xi', '530', '530i', '530xd',
#         '530xi', '535d', '535d xdrive', '535i', '535i gt',
#         '535i gt xdrive', '535i xdrive', '535xi', '540i', '545i', '550i',
#         '550i gt', '550i gt xdrive', '550i xdrive', '6 series',
#         '6 series gran coupe', '6 series gran turismo', '640i',
#         '640i gran coupe', '640i xdrive', '640i xdrive gran coupe',
#         '645ci', '650ci', '650i', '650i gran coupe',
#         '650i gran coupe xdrive', '650i xdrive', '650i xdrive gran coupe',
#         '7 series', '740i', '740il', '740ld xdrive', '740ld xdrvie',
#         '740li', '740li xdrive', '745i', '745li', '750i', '750i xdrive',
#         '750il', '750li', '750li xdrive', '760i', '760li', '8 series',
#         '8 series gran coupe', 'activehybrid 3', 'activehybrid 5',
#         'activehybrid 7', 'alpina b6', 'alpina b6 gran coupe',
#         'alpina b6 xdrive gran coupe', 'alpina b7', 'alpina b7 xdrive',
#         'alpina b7l', 'alpina b7l xdrive', 'c600 sport', 'c650gt', 'e36',
#         'e46', 'e90', 'f650 enduro', 'f650cs', 'f650cs abs', 'f650gs',
#         'f650gs abs', 'f650gs dakar', 'f650gs dakar abs', 'f700gs',
#         'f800gs', 'f800gs adventure', 'f800gt', 'f800r', 'f800s', 'f800st',
#         'g450x', 'g650 xchallenge', 'g650 xcountry', 'g650 xmoto',
#         'g650gs', 'g650gs sertao', 'hp2 enduro', 'hp2 megamoto',
#         'hp2 sport', 'hp4', 'hp4 competition', 'i3', 'i4', 'i5', 'i7',
#         'i8', 'ix', 'k1200gt', 'k1200lt', 'k1200lt exodus', 'k1200ltc',
#         'k1200lti icon', 'k1200r', 'k1200r sport', 'k1200rs', 'k1200s',
#         'k1300gt', 'k1300r', 'k1300s', 'k1300s 30 jahre k modelle',
#         'k1600gt', 'k1600gt sport', 'k1600gtl', 'k1600gtl exclusive', 'm1',
#         'm135i', 'm135i xdrive', 'm140i', 'm2', 'm235i', 'm235i xdrive',
#         'm240i', 'm240i xdrive', 'm3', 'm340d xdrive', 'm340i xdrive',
#         'm4', 'm440d xdrive', 'm440i xdrive', 'm5', 'm535i', 'm6',
#         'm6 gran coupe', 'm8', 'r nine t', 'r1100rl', 'r1100rs abs',
#         'r1100rt', 'r1100s', 'r1100s abs', 'r1100s boxer cup',
#         'r1100s boxer cup replica', 'r1100sa', 'r1150gs',
#         'r1150gs adventure', 'r1150gs sport', 'r1150r', 'r1150r roadster',
#         'r1150rs', 'r1150rt', 'r1200c', 'r1200c avantgarde',
#         'r1200c classic', 'r1200c euro', 'r1200c independent',
#         'r1200c montana', 'r1200c montauk', 'r1200c phoenix',
#         'r1200c stiletto', 'r1200cl', 'r1200gs', 'r1200gs adventure',
#         'r1200gs hp2', 'r1200r', 'r1200r classic', 'r1200rt', 'r1200s',
#         'r1200st', 'r850r', 'rg1200gs', 's1000r', 's1000rr', 'x1', 'x2',
#         'x3', 'x3 m', 'x4', 'x4 m', 'x5', 'x5 m', 'x6', 'x6 m', 'x7', 'xm',
#         'z3', 'z4', 'z4 m', 'z8'], dtype='<U27'),
#  'bobcat': array(['2100 gas', '2200g gas', '2200s diesel', '2200sg gas', '2300',
#         '3200 4x2 gas', '3400 4x4 diesel', '3400 4x4 gas',
#         '3400xl 4x4 diesel', '3400xl 4x4 gas', '3600 4x4', '3650 4x4',
#         'toolcat 5600', 'toolcat 5610'], dtype='<U17'),
#  'bombardier': array(['ds250', 'ds50', 'ds650', 'ds650 baja', 'ds650 baja x',
#         'ds650 racer', 'ds650 x', 'ds90', 'ds90 4 stroke',
#         'outlander 330 ho 2x4', 'outlander 330 ho 4x4',
#         'outlander 400 ho 2x4', 'outlander 400 ho 4x4',
#         'outlander 400 ho 4x4 xt', 'outlander 650 ho efi 4x4',
#         'outlander 650 ho efi 4x4 xt', 'outlander 800 ho efi 4x4',
#         'outlander 800 ho efi 4x4 xt', 'outlander max 400 ho',
#         'outlander max 400 ho xt', 'outlander max 650 ho efi 4x4',
#         'outlander max 650 ho efi 4x4 xt', 'outlander max 800 ho efi 4x4',
#         'outlander max 800 ho efi 4x4 xt', 'quest 50', 'quest 500 4x4',
#         'quest 500 4x4 xt', 'quest 650 4x4', 'quest 650 4x4 max',
#         'quest 650 4x4 xt', 'quest 90', 'quest 90 4 stroke', 'rally 200',
#         'traxter 500 4x4 auto', 'traxter 500 4x4 auto xt',
#         'traxter 500 auto 4x4 cvt', 'traxter 500 xl',
#         'traxter 650 4x4 auto cvt', 'traxter 650 4x4 auto cvt xt',
#         'traxter max 500 4x4 auto', 'traxter max 500 4x4 auto xt',
#         'traxter max 650 4x4 auto cvt', 'traxter max 650 4x4 auto cvt xt'],
#        dtype='<U31'),
#  'buell': array(['1125cr', '1125r', 'blast', 'lightning cityx xb9sx', 'm2 cyclone',
#         'm2l cyclone', 's3 thunderbolt', 's3t thunderbolt', 'x1 lightning',
#         'x1w white lightning', 'xb12r firebolt', 'xb12s lightning',
#         'xb12scg lightning', 'xb12ss lightning long', 'xb12stt lightning',
#         'xb12stt lightning super tt', 'xb12x ulysses',
#         'xb12xp ulysses police', 'xb12xt ulysses', 'xb9r firebolt',
#         'xb9s lightning', 'xb9sl', 'xb9sx lightning',
#         'xb9sx lightning cityx'], dtype='<U26'),
#  'bugatti': array(['veyron 16 4'], dtype='<U11'),
#  'buick': array(['allure', 'cascada', 'century', 'enclave', 'encore', 'encore gx',
#         'envision', 'envista', 'lacrosse', 'lesabre', 'lucerne',
#         'park avenue', 'rainier', 'regal', 'regal sportback',
#         'regal tourx', 'rendezvous', 'riviera', 'roadmaster', 'skylark',
#         'terraza', 'verano', 'wildcat'], dtype='<U15'),
#  'cadillac': array(['allante', 'ats', 'ats coupe', 'ats v', 'bls', 'brougham',
#         'catera', 'celestiq', 'ct4', 'ct5', 'ct6', 'ct6 v', 'cts', 'cts v',
#         'cts v coupe', 'deville', 'dts', 'eldorado', 'elr', 'escalade',
#         'escalade esv', 'escalade ext', 'escalade iq', 'fleetwood',
#         'lyriq', 'optiq', 'seville', 'sixty special', 'srx', 'sts',
#         'vistiq', 'xlr', 'xt4', 'xt5', 'xt6', 'xts'], dtype='<U13'),
#  'can am': array(['commander 1000', 'commander 1000 dps', 'commander 1000 ltd',
#         'commander 1000 x', 'commander 1000 xt', 'commander 1000 xt p',
#         'commander 800r', 'commander 800r xt', 'commander dps 1000',
#         'commander dps 800r', 'commander max 1000 dps',
#         'commander max 1000 xt', 'ds 250', 'ds 450', 'ds 450 efi',
#         'ds 450 efi x mx', 'ds 450 efi x xc', 'ds 450 x', 'ds 450 x mx',
#         'ds 450 x xc', 'ds 50', 'ds 650 x', 'ds 70', 'ds 90', 'ds 90 x',
#         'maverick 1000r', 'maverick max 1000r',
#         'maverick max x rs dps 1000r', 'maverick x mr 1000r',
#         'maverick x rs 1000r', 'maverick x rs dps 1000r',
#         'maverick x xc dps 1000r', 'outlander 1000 efi',
#         'outlander 1000 efi dps', 'outlander 1000 efi xt',
#         'outlander 1000 efi xt p', 'outlander 1000 x mr',
#         'outlander 400 efi', 'outlander 400 efi xt', 'outlander 400 ho',
#         'outlander 400 ho efi', 'outlander 400 ho efi xt',
#         'outlander 400 ho xt', 'outlander 500 efi',
#         'outlander 500 efi dps', 'outlander 500 efi xt',
#         'outlander 500 ho 4x4 efi', 'outlander 500 ho 4x4 efi xt',
#         'outlander 500 ho 4x4 efi xt p', 'outlander 650 efi',
#         'outlander 650 efi dps', 'outlander 650 efi xt',
#         'outlander 650 efi xt p', 'outlander 650 ho 4x4 efi',
#         'outlander 650 ho 4x4 efi xt', 'outlander 650 x mr',
#         'outlander 800 ho 4x4 efi', 'outlander 800 ho 4x4 efi xt',
#         'outlander 800r efi', 'outlander 800r efi dps',
#         'outlander 800r efi x mr', 'outlander 800r efi x xc',
#         'outlander 800r efi xt', 'outlander 800r efi xt p',
#         'outlander max 1000 efi dps', 'outlander max 1000 efi ltd',
#         'outlander max 1000 efi xt', 'outlander max 1000 efi xt p',
#         'outlander max 400 efi', 'outlander max 400 efi xt',
#         'outlander max 400 ho', 'outlander max 400 ho efi',
#         'outlander max 400 ho efi xt', 'outlander max 400 ho xt',
#         'outlander max 500 efi', 'outlander max 500 efi dps',
#         'outlander max 500 efi xt', 'outlander max 500 ho efi',
#         'outlander max 500 ho efi ltd', 'outlander max 500 ho efi xt',
#         'outlander max 500 ho efi xt p', 'outlander max 650 efi',
#         'outlander max 650 efi dps', 'outlander max 650 efi xt',
#         'outlander max 650 efi xt p', 'outlander max 650 ho efi',
#         'outlander max 650 ho efi xt', 'outlander max 800 ho efi',
#         'outlander max 800 ho efi ltd', 'outlander max 800 ho efi xt',
#         'outlander max 800r efi', 'outlander max 800r efi dps',
#         'outlander max 800r efi ltd', 'outlander max 800r efi xt',
#         'outlander max 800r efi xt p', 'rally 200', 'renegade 1000',
#         'renegade 1000 efi x xc', 'renegade 1000 x xc', 'renegade 500',
#         'renegade 800', 'renegade 800 x', 'renegade 800 x xc',
#         'renegade 800r', 'renegade 800r efi x xc', 'renegade 800r x xc',
#         'spyder gs se5', 'spyder gs sm5'], dtype='<U29'),
#  'cannondale': array(['blaze 440', 'c440r', 'cannibal 440', 'e440', 'e440a', 'e440r',
#         'fx400', 'glamis 440', 'moto 440', 'mx400', 's440', 'speed 440',
#         'x440'], dtype='<U12'),
#  'citroen': array(['2cv', 'acadiane', 'ami', 'ami', 'ax', 'basalt', 'bx', 'c1', 'c2',
#         'c3', 'c3 aircross', 'c3 picasso', 'c3 pluriel', 'c4', 'c4 cactus',
#         'c4 picasso', 'c4 x', 'c5', 'c5 aircross', 'c5 x', 'c6', 'c8',
#         'cx', 'ds', 'dyane', 'e berlingo', 'e c3', 'e c4', 'e c4 x',
#         'e c5 aircross', 'e mehari', 'e spacetourer', 'evasion', 'gs',
#         'gsa', 'ln', 'lna', 'mehari', 'nemo', 'rosalie', 'saxo', 'sm',
#         'synergie', 'traction avant', 'visa', 'xantia', 'xm', 'xsara',
#         'xsara picasso', 'zx'], dtype='<U14'),
#  'chance coach transit bus': array(['ah 28', 'cng 28'], dtype='<U6'),
#  'chevrolet': array(['1500 extended cab', '1500 regular cab', '2500 crew cab',
#         '2500 extended cab', '2500 hd extended cab', '2500 hd regular cab',
#         '2500 regular cab', '3500 crew cab', '3500 extended cab',
#         '3500 hd extended cab', '3500 hd regular cab', '3500 regular cab',
#         'apv cargo', 'astra', 'astro', 'astro cargo', 'astro passenger',
#         'avalanche', 'avalanche 1500', 'avalanche 2500', 'aveo', 'aveo5',
#         'b7', 'beretta', 'blazer', 'blazer ev', 'bolt euv', 'bolt ev',
#         'c3500', 'c3500hd', 'c4500 kodiak', 'c5500 kodiak', 'c6500 kodiak',
#         'c7500 kodiak', 'camaro', 'caprice', 'caprice classic',
#         'captiva sport', 'cavalier', 'chevy', 'chevy monza',
#         'chevy pickup', 'cheyenne', 'cheyenne 2500', 'city express',
#         'classic', 'cobalt', 'colorado', 'colorado crew cab',
#         'colorado extended cab', 'colorado regular cab', 'corsa',
#         'corsica', 'corvette', 'cruze', 'cruze limited', 'epica',
#         'equinox', 'equinox ev', 'express', 'express 1500',
#         'express 1500 cargo', 'express 1500 passenger', 'express 2500',
#         'express 2500 cargo', 'express 2500 passenger', 'express 3500',
#         'express 3500 cargo', 'express 3500 passenger', 'express 4500',
#         'express cargo', 'express pasajeros', 'g series 1500',
#         'g series 2500', 'g series 3500', 'g series g10', 'g series g20',
#         'g series g30', 'g30', 'hhr', 'impala', 'impala limited', 'lumina',
#         'lumina apv', 'lumina cargo', 'lumina passenger', 'luv', 'malibu',
#         'malibu classic', 'malibu limited', 'matiz', 'meriva', 'metro',
#         'monte carlo', 'optra', 'orlando', 'p30', 'prizm', 'r25', 's10',
#         's10 blazer', 's10 crew cab', 's10 extended cab',
#         's10 regular cab', 'silverado 1500', 'silverado 1500 crew cab',
#         'silverado 1500 double cab', 'silverado 1500 extended cab',
#         'silverado 1500 hd', 'silverado 1500 hd crew cab',
#         'silverado 1500 ld', 'silverado 1500 ld double cab',
#         'silverado 1500 limited crew cab',
#         'silverado 1500 limited double cab',
#         'silverado 1500 limited regular cab', 'silverado 1500 regular cab',
#         'silverado 2500', 'silverado 2500 crew cab',
#         'silverado 2500 extended cab', 'silverado 2500 hd',
#         'silverado 2500 hd crew cab', 'silverado 2500 hd double cab',
#         'silverado 2500 hd extended cab', 'silverado 2500 hd regular cab',
#         'silverado 2500 regular cab', 'silverado 2500hd', 'silverado 3500',
#         'silverado 3500 crew cab', 'silverado 3500 extended cab',
#         'silverado 3500 hd', 'silverado 3500 hd crew cab',
#         'silverado 3500 hd double cab', 'silverado 3500 hd extended cab',
#         'silverado 3500 hd regular cab', 'silverado 3500 regular cab',
#         'silverado 3500hd', 'silverado classic 1500 crew cab',
#         'silverado classic 1500 extended cab',
#         'silverado classic 1500 hd crew cab',
#         'silverado classic 1500 regular cab',
#         'silverado classic 2500 hd crew cab',
#         'silverado classic 2500 hd extended cab',
#         'silverado classic 2500 hd regular cab',
#         'silverado classic 3500 crew cab',
#         'silverado classic 3500 extended cab',
#         'silverado classic 3500 regular cab', 'silverado ev', 'sonic',
#         'sonora', 'spark', 'spark ev', 'sportvan g10', 'sportvan g20',
#         'sportvan g30', 'ss', 'ssr', 'suburban', 'suburban 1500',
#         'suburban 2500', 'suburban 3500hd', 't6500', 't7500', 'tahoe',
#         'tahoe new', 'tornado', 'tracker', 'trailblazer',
#         'trailblazer ext', 'traverse', 'traverse limited', 'trax',
#         'uplander', 'uplander cargo', 'uplander passenger', 'vectra',
#         'venture', 'venture cargo', 'venture passenger', 'volt',
#         'w3500 tiltmaster', 'w4500 tiltmaster', 'w5500 tiltmaster',
#         'w5500hd tiltmaster', 'zafira'], dtype='<U38'),
#  'chrysler': array(['200', '300', '300c', '300m', 'aspen', 'cirrus', 'concorde',
#         'crossfire', 'fifth ave', 'grand voyager', 'imperial', 'intrepid',
#         'lebaron', 'lhs', 'neon', 'new yorker', 'pacifica',
#         'pacifica hybrid', 'prowler', 'pt cruiser', 'sebring',
#         'town and country', 'town country', 'voyager'], dtype='<U16'),
#  'cobra': array(['ch2', 'cm50', 'cx50 jr', 'cx50 oi', 'cx50 sr', 'cx65',
#         'cx65 c a r d', 'dc65', 'ecx50', 'ecx70', 'king', 'p3', 'pw3'],
#        dtype='<U12'),
#  'coda': array(['sedan'], dtype='<U5'),
#  'country coach motorhome': array(['affinity', 'allure', 'inspire', 'intrigue', 'lexa', 'magna',
#         'tribute'], dtype='<U8'),
#  'crane carrier': array(['centurion'], dtype='<U9'),
#  'cub cadet': array(['4x2 fis fis se', '4x4', 'big country 4x2', 'volunteer 4x2',
#         'volunteer 4x4 efi', 'volunteer 4x4d'], dtype='<U17'),
#  'daewoo': array(['lanos', 'leganza', 'nubira'], dtype='<U7'),
#  'daihatsu': array(['charade', 'rocky'], dtype='<U7'),
#  'dodge': array(['atos', 'attitude', 'avenger', 'caliber', 'caravan',
#         'caravan cargo', 'caravan passenger', 'challenger', 'charger',
#         'colt', 'd150 club cab', 'd150 regular cab', 'd250 club cab',
#         'd250 regular cab', 'd350 club cab', 'd350 regular cab', 'dakota',
#         'dakota club cab', 'dakota crew cab', 'dakota extended cab',
#         'dakota quad cab', 'dakota regular cab', 'dart', 'daytona',
#         'durango', 'dynasty', 'grand caravan', 'grand caravan cargo',
#         'grand caravan passenger', 'h100', 'hornet', 'i10', 'intrepid',
#         'journey', 'magnum', 'monaco', 'neon', 'nitro', 'ram 1500',
#         'ram 1500 club cab', 'ram 1500 crew cab', 'ram 1500 mega cab',
#         'ram 1500 pickup', 'ram 1500 quad cab', 'ram 1500 regular cab',
#         'ram 1500 truck', 'ram 1500 van', 'ram 2500', 'ram 2500 club cab',
#         'ram 2500 crew cab', 'ram 2500 mega cab', 'ram 2500 pickup',
#         'ram 2500 quad cab', 'ram 2500 regular cab', 'ram 2500 truck',
#         'ram 2500 van', 'ram 3500', 'ram 3500 club cab',
#         'ram 3500 crew cab', 'ram 3500 mega cab', 'ram 3500 pickup',
#         'ram 3500 quad cab', 'ram 3500 regular cab', 'ram 3500 truck',
#         'ram 3500 van', 'ram 4000', 'ram 4500', 'ram 50 regular cab',
#         'ram 5500', 'ram van 1500', 'ram van 2500', 'ram van 3500',
#         'ram van b150', 'ram van b250', 'ram van b350', 'ram wagon 1500',
#         'ram wagon 2500', 'ram wagon 3500', 'ram wagon b150',
#         'ram wagon b250', 'ram wagon b350', 'ramcharger', 'shadow',
#         'spirit', 'sprinter 2500', 'sprinter 2500 cargo',
#         'sprinter 2500 passenger', 'sprinter 3500', 'sprinter 3500 cargo',
#         'stealth', 'stratus', 'sx 2 0', 'van 1000', 'verna', 'viper'],
#        dtype='<U23'),
#  'ducati': array(['1098', '1098 r', '1098 r bayliss le', '1098 s',
#         '1098 s tricolore', '1198', '1198 r corse', '1198 s',
#         '1198 s corse', '1199 panigale', '1199 panigale r',
#         '1199 panigale s', '1199 panigale s tricolore', '748',
#         '748 monoposto', '748r', '748r biposto', '748s', '748s monoposto',
#         '749', '749r', '749s', '750', '750 sport', '800', '800 sport',
#         '848', '848 evo', '848 evo corse se', '899 panigale', '900', '996',
#         '996 biposto', '996 monoposto', '996r', '996s', '996s monoposto',
#         '998 biposto', '998 f edition biposto', '998 f edition monoposto',
#         '998 matrix', '998 monoposto', '998r', '998s', '998s bostrom',
#         '999', '999r', '999r fila', '999r xerox', '999s', 'desmosedici rr',
#         'diavel', 'diavel amg', 'diavel carbon', 'diavel cromo',
#         'diavel dark', 'diavel strada', 'gt1000', 'gt1000 touring',
#         'hypermotard', 'hypermotard 1100', 'hypermotard 1100 evo',
#         'hypermotard 1100 evo sp', 'hypermotard 1100 s', 'hypermotard 796',
#         'hypermotard sp', 'mh900e', 'monster 1000', 'monster 1000 dark',
#         'monster 1000s', 'monster 1100', 'monster 1100 s', 'monster 400',
#         'monster 400 dark', 'monster 400 metallic', 'monster 400s',
#         'monster 600 dark', 'monster 620', 'monster 620 capirex',
#         'monster 620 dark', 'monster 620 matrix', 'monster 620s',
#         'monster 696', 'monster 750', 'monster 750 dark',
#         'monster 750 metallic', 'monster 796', 'monster 800',
#         'monster 800s', 'monster 900', 'monster 900 cromo',
#         'monster 900 dark', 'monster 900 metallic', 'monster 900s',
#         'monster s2r', 'monster s2r 1000', 'monster s2r 800',
#         'monster s2r dark', 'monster s4', 'monster s4 fogarty',
#         'monster s4r', 'monster s4r testastretta', 'monster s4rs',
#         'monster s4rs testastretta', 'monster s4rs tricolore',
#         'multistrada 1000 ds', 'multistrada 1000s ds', 'multistrada 1100',
#         'multistrada 1100 s', 'multistrada 1200', 'multistrada 1200 s',
#         'multistrada 1200 s granturismo', 'multistrada 1200 s pikes peak',
#         'multistrada 1200 s sport', 'multistrada 1200 s touring',
#         'multistrada 620', 'multistrada 620 dark', 'st2', 'st3',
#         'st3s abs', 'st4', 'st4s', 'st4s abs', 'streetfighter',
#         'streetfighter s'], dtype='<U30'),
#  'eagle': array(['premier', 'summit', 'talon', 'vision'], dtype='<U7'),
#  'el dorado': array(['axess', 'e z rider', 'e z rider ii', 'e z rider ii max',
#         'escort re', 'transmark re'], dtype='<U16'),
#  'e ton': array(['axl 50', 'axl 90', 'beamer', 'beamer 50', 'beamer ii',
#         'beamer iii', 'beamer matrix', 'beamer matrix ii', 'beamer r2',
#         'beamer r4 150', 'dxl 90', 'lightning 50', 'matrix 150',
#         'matrix 50', 'matrix r4 150', 'rover', 'rover gt', 'sierra 90',
#         'sport 150', 'sport 50', 'txl 50', 'txl 90', 'vector 250r',
#         'viper 150r', 'viper 50', 'viper 50m mini', 'viper 70',
#         'viper 70 4 stroke', 'viper 70 silver series',
#         'viper 70m 4 stroke', 'viper 90', 'viper 90 silver series',
#         'viper 90r 4 stroke', 'viper 90r reverse',
#         'viper 90r silver series', 'viper jr', 'yukon', 'yukon cxl 150',
#         'yukon ii cxl 150', 'yxl 150'], dtype='<U23'),
#  'ferrari': array(['296 gtb', '360', '430 scuderia', '456 m', '456 m gt', '456 m gta',
#         '458 italia', '458 speciale', '458 spider', '488 gtb', '488 pista',
#         '488 spider', '550 maranello', '575 m maranello', '599 gtb',
#         '599 gtb fiorano', '599 gto', '612 scaglietti', '812 competizione',
#         '812 competizione a', '812 gts', '812 superfast', 'california',
#         'california t', 'enzo', 'f12 berlinetta', 'f12berlinetta', 'f430',
#         'f8', 'ff', 'gtc4lusso', 'laferrari', 'portofino', 'roma', 'sf90',
#         'superamerica'], dtype='<U18'),
#  'fiat': array(['124 spider', '500', '500 abarth', '500c', '500c abarth', '500e',
#         '500l', '500x', 'albea', 'cinquecento', 'ducato', 'grande punto',
#         'palio', 'panda', 'scudo', 'stilo'], dtype='<U12'),
#  'fisker': array(['alaska', 'karma', 'ocean', 'pear', 'ronin'], dtype='<U6'),
#  'ford': array(['aerostar cargo', 'aerostar passenger', 'aspire', 'bronco',
#         'bronco sport', 'c max', 'c max energi', 'c max hybrid',
#         'club wagon', 'contour', 'courier', 'crown victoria', 'e 150',
#         'e 150 club wagon', 'e 150 econoline',
#         'e 150 econoline club wagon', 'e 250', 'e 250 econoline',
#         'e 250 super duty', 'e 350', 'e 350 club wagon', 'e 350 econoline',
#         'e 350 econoline club wagon', 'e 350 super duty',
#         'e 450 econoline', 'e 450 econoline super duty',
#         'e 450 econoline super duty s',
#         'e 450 econoline super duty stripped', 'e 450 super duty',
#         'e 450 super duty stripped chassis', 'e 550 econoline super duty',
#         'e 550 super duty', 'e super duty', 'e transit 350 cargo van',
#         'e150 cargo', 'e150 passenger', 'e150 super duty cargo',
#         'e150 super duty passenger', 'e250 cargo', 'e250 super duty cargo',
#         'e350 super duty cargo', 'e350 super duty passenger', 'econoline',
#         'econoline e150 cargo', 'econoline e150 passenger',
#         'econoline e250 cargo', 'econoline e350 cargo',
#         'econoline e350 super duty cargo',
#         'econoline e350 super duty passenger', 'econoline van',
#         'econoline wagon', 'ecosport', 'edge', 'escape',
#         'escape plug in hybrid', 'escort', 'excursion', 'expedition',
#         'expedition el', 'expedition max', 'explorer', 'explorer sport',
#         'explorer sport trac', 'f 100 ranger', 'f 150', 'f 150 heritage',
#         'f 250', 'f 250 super duty', 'f 350', 'f 350 super duty', 'f 450',
#         'f 450 super duty', 'f 550', 'f 550 super duty',
#         'f150 heritage regular cab', 'f150 heritage super cab',
#         'f150 lightning', 'f150 regular cab', 'f150 super cab',
#         'f150 supercrew cab', 'f250 crew cab', 'f250 regular cab',
#         'f250 super cab', 'f250 super duty crew cab',
#         'f250 super duty regular cab', 'f250 super duty super cab',
#         'f350 crew cab', 'f350 regular cab', 'f350 super cab',
#         'f350 super duty crew cab', 'f350 super duty regular cab',
#         'f350 super duty super cab', 'f450 super duty crew cab',
#         'f450 super duty regular cab', 'f53', 'f650', 'f750', 'festiva',
#         'fiesta', 'fiesta ikon', 'five hundred', 'flex', 'focus',
#         'focus europa', 'focus st', 'freestar', 'freestar cargo',
#         'freestar passenger', 'freestyle', 'fusion', 'fusion energi',
#         'fusion hybrid', 'fusion plug in hybrid', 'galaxie', 'galaxy',
#         'grand marquis', 'gt', 'ikon', 'ka', 'lcf', 'lobo', 'maverick',
#         'mondeo', 'mustang', 'mustang mach e', 'police interceptor sedan',
#         'police interceptor utility', 'probe', 'ranger',
#         'ranger regular cab', 'ranger super cab', 'ranger supercab',
#         'ranger supercrew', 'sable', 'shelby gt350', 'shelby gt500',
#         'special service police sedan', 'taurus', 'taurus x', 'tempo',
#         'thunderbird', 'transit', 'transit 150', 'transit 150 cargo van',
#         'transit 150 crew van', 'transit 150 passenger van',
#         'transit 150 van', 'transit 150 wagon', 'transit 250',
#         'transit 250 cargo van', 'transit 250 crew van', 'transit 250 van',
#         'transit 350', 'transit 350 cargo van', 'transit 350 crew van',
#         'transit 350 hd', 'transit 350 hd cargo van',
#         'transit 350 hd crew van', 'transit 350 hd van',
#         'transit 350 passenger van', 'transit 350 van',
#         'transit 350 wagon', 'transit cargo van', 'transit connect',
#         'transit connect cargo', 'transit connect cargo van',
#         'transit connect passenger', 'transit connect passenger wagon',
#         'transit crew van', 'transit passenger van', 'transit van',
#         'transit wagon', 'windstar', 'windstar cargo',
#         'windstar passenger', 'zx2'], dtype='<U35'),
#  'freightliner': array(['108sd', '114sd', 'argosy', 'b2', 'business class m2', 'cascadia',
#         'century class', 'classic', 'classic xl', 'columbia', 'condor',
#         'coronado', 'fc70', 'fc80', 'fl106', 'fl112', 'fl50', 'fl60',
#         'fl70', 'fl80', 'fs65', 'm2 106', 'm2 112', 'mt35', 'mt45', 'mt55',
#         'sprinter 1500 cargo', 'sprinter 1500 passenger', 'sprinter 2500',
#         'sprinter 2500 cargo', 'sprinter 2500 crew',
#         'sprinter 2500 passenger', 'sprinter 3500', 'sprinter 3500 cargo',
#         'sprinter 3500 crew', 'sprinter 3500 xd crew',
#         'sprinter 3500xd cargo', 'sprinter 4500 cargo',
#         'sprinter 4500 crew', 'sprinter worker cargo',
#         'sprinter worker passenger', 'xc'], dtype='<U25'),
#  'gas gas': array(['enducross ec 200', 'enducross ec 250', 'enducross ec 300',
#         'pampera 280'], dtype='<U16'),
#  'genesis': array(['electrified g80', 'electrified gv70', 'g70', 'g80', 'g90', 'gv60',
#         'gv70', 'gv80', 'gv80 coupe'], dtype='<U16'),
#  'geo': array(['metro', 'prizm', 'storm', 'tracker'], dtype='<U7'),
#  'gillig': array(['low floor'], dtype='<U9'),
#  'gmc': array(['1500 club coupe', '1500 regular cab', '2500 club coupe',
#         '2500 crew cab', '2500 hd club coupe', '2500 hd extended cab',
#         '2500 hd regular cab', '2500 regular cab', '3500 club coupe',
#         '3500 crew cab', '3500 extended cab', '3500 regular cab', 'acadia',
#         'acadia limited', 'b7', 'c3500', 'c3500hd', 'c4500 topkick',
#         'c5500 topkick', 'c6500 topkick', 'c7500 topkick', 'canyon',
#         'canyon crew cab', 'canyon extended cab', 'canyon regular cab',
#         'envoy', 'envoy xl', 'envoy xuv', 'hummer ev pickup',
#         'hummer ev suv', 'jimmy', 'rally wagon 1500', 'rally wagon 2500',
#         'rally wagon 3500', 'rally wagon g2500', 'rally wagon g3500',
#         'safari', 'safari cargo', 'safari passenger', 'savana',
#         'savana 1500', 'savana 1500 cargo', 'savana 1500 passenger',
#         'savana 2500', 'savana 2500 cargo', 'savana 2500 passenger',
#         'savana 3500', 'savana 3500 cargo', 'savana 3500 passenger',
#         'savana 4500', 'savana cargo', 'sierra', 'sierra 1500',
#         'sierra 1500 crew cab', 'sierra 1500 double cab',
#         'sierra 1500 extended cab', 'sierra 1500 hd',
#         'sierra 1500 hd crew cab', 'sierra 1500 limited',
#         'sierra 1500 limited crew cab', 'sierra 1500 limited double cab',
#         'sierra 1500 limited regular cab', 'sierra 1500 regular cab',
#         'sierra 2500', 'sierra 2500 crew cab', 'sierra 2500 extended cab',
#         'sierra 2500 hd', 'sierra 2500 hd crew cab',
#         'sierra 2500 hd double cab', 'sierra 2500 hd extended cab',
#         'sierra 2500 hd regular cab', 'sierra 2500 regular cab',
#         'sierra 2500hd', 'sierra 3500', 'sierra 3500 crew cab',
#         'sierra 3500 extended cab', 'sierra 3500 hd',
#         'sierra 3500 hd crew cab', 'sierra 3500 hd double cab',
#         'sierra 3500 hd extended cab', 'sierra 3500 hd regular cab',
#         'sierra 3500 regular cab', 'sierra 3500hd', 'sierra c3',
#         'sierra classic 1500 crew cab', 'sierra classic 1500 extended cab',
#         'sierra classic 1500 hd crew cab',
#         'sierra classic 1500 regular cab', 'sierra classic 2500 crew cab',
#         'sierra classic 2500 hd crew cab',
#         'sierra classic 2500 hd extended cab',
#         'sierra classic 2500 hd regular cab',
#         'sierra classic 3500 crew cab', 'sierra classic 3500 extended cab',
#         'sierra classic 3500 regular cab', 'sierra denali', 'sierra ev',
#         'sonoma', 'sonoma club cab', 'sonoma club coupe cab',
#         'sonoma crew cab', 'sonoma extended cab', 'sonoma regular cab',
#         'suburban', 'suburban 1500', 'suburban 2500', 't6500', 't7500',
#         'terrain', 'vandura', 'vandura 1500', 'vandura 2500',
#         'vandura 3500', 'vandura g1500', 'vandura g2500', 'vandura g3500',
#         'w3500 forward', 'w4500 forward', 'w5500 forward',
#         'w5500hd forward', 'yukon', 'yukon denali', 'yukon xl',
#         'yukon xl 1500', 'yukon xl 2500'], dtype='<U35'),
#  'harley davidson': array(['fld switchback', 'flhr road king', 'flhrc road king classic',
#         'flhrci road king classic', 'flhri road king',
#         'flhrs road king custom', 'flhrse3 screamin eagle road king',
#         'flhrse4 screamin eagle road king', 'flhrse5 cvo road king',
#         'flhrse6 cvo road king', 'flhrsei screamin eagle road king',
#         'flhrsei2 screamin eagle road king 2', 'flhrsi road king custom',
#         'flht electra glide standard', 'flhtc electra glide classic',
#         'flhtci electra glide classic',
#         'flhtcse screamin eagle electra glid',
#         'flhtcse2 screamin eagle electra gli',
#         'flhtcu electra glide ultra classic',
#         'flhtcui electra glide ultra classic',
#         'flhtcuse screamin eagle ultra class',
#         'flhtcuse2 screamin eagle ultra clas',
#         'flhtcuse3 screamin eagle ultra clas',
#         'flhtcuse4 cvo ultra classic electra',
#         'flhtcuse5 cvo ultra classic electra',
#         'flhtcuse6 cvo ultra classic electra',
#         'flhtcuse7 cvo ultra classic electra',
#         'flhtcuse8 cvo ultra classic electra', 'flhtcutg tri glide ultra',
#         'flhtcutg tri glide ultra classic', 'flhti electra glide standard',
#         'flhtk electra glide ultra limited', 'flhtkse cvo limited',
#         'flhx street glide', 'flhxi street glide',
#         'flhxs street glide special', 'flhxse cvo street glide',
#         'flhxse2 cvo street glide', 'flhxse3 cvo street glide',
#         'flhxxx street glide trike', 'fls softail slim',
#         'flst heritage softail', 'flstc heritage softail classic',
#         'flstci heritage softail classic', 'flstf fat boy',
#         'flstfb fat boy lo', 'flstfi fat boy',
#         'flstfse screamin eagle fat boy',
#         'flstfse2 screamin eagle fat boy', 'flsti heritage softail',
#         'flstn softail deluxe', 'flstni softail deluxe',
#         'flstnse cvo softail deluxe', 'flsts heritage springer',
#         'flstsb cross bones', 'flstsc softail springer classic',
#         'flstsci softail springer classic',
# ...
#         'lt a750x kingquad axi 4x4', 'lt a750x kingquad axi 4x4 le',
#         'lt f160 quadrunner', 'lt f250 ozark', 'lt f250 quadrunner',
#         'lt f250f quadrunner 4x4', 'lt f300f kingquad 4x4',
#         'lt f400 eiger 2x4', 'lt f400f eiger 4x4', 'lt f400f kingquad fs',
#         'lt f400f kingquad fsi', 'lt f400f kingquad fsi le',
#         'lt f500f quadrunner 4x4', 'lt f500f vinson 500 4x4',
#         'lt r450 quadracer', 'lt v700f twin peaks 700 4x4',
#         'lt z250 quadsport z', 'lt z400 quadsport z',
#         'lt z400 quadsport z le', 'lt z50 quadsport', 'lt z90 quadsport',
#         'lt160', 'lt80 quadsport', 'm109r boulevard',
#         'm109r boulevard b o s s', 'm109r2 boulevard', 'm50 boulevard',
#         'm50 boulevard limited', 'm50 boulevard se', 'm50b boulevard',
#         'm90 boulevard', 'm95 boulevard', 'quv620f', 'reno', 'rm100',
#         'rm125', 'rm250', 'rm60', 'rm65', 'rm80', 'rm85', 'rmx450z',
#         'rmz250', 'rmz450', 's40 boulevard', 's50 boulevard',
#         's83 boulevard', 'samurai', 'sfv650', 'sfv650 gladius', 'sidekick',
#         'sv1000 s', 'sv650', 'sv650a abs', 'sv650s', 'sv650sa abs',
#         'swift', 'swift', 'sx4', 'sx4 crossover', 'tl1000r', 'tl1000s',
#         'tu250', 'tu250x', 'uh200 burgman abs', 'verona', 'vitara',
#         'vl1500 intruder', 'vl800 intruder volusia', 'vs1400gl intruder',
#         'vs800gl intruder', 'vz1600 marauder', 'vz800 marauder', 'x 90',
#         'xl 7', 'xl7'], dtype='<U35'),
#  'tesla': array(['cybertruck', 'model 3', 'model s', 'model x', 'model y',
#         'roadster', 's', 'x'], dtype='<U10'),
#  'tm': array(['en250', 'en250f', 'en450f', 'mx100', 'mx250', 'mx250f', 'mx450f',
#         'mx85 17 14', 'smm450f', 'smr450f', 'smx450f', 'smx530f',
#         'smx660f', 'xc250'], dtype='<U10'),
#  'toyota': array(['4runner', '86', 'avalon', 'avalon hybrid', 'avanza', 'bz4x',
#         'c hr', 'camry', 'camry hybrid', 'celica', 'corolla',
#         'corolla cross', 'corolla cross hybrid', 'corolla hatchback',
#         'corolla hybrid', 'corolla im', 'cressida', 'crown',
#         'crown signia', 'echo', 'fj cruiser', 'gr corolla', 'gr supra',
#         'gr86', 'grand highlander', 'grand highlander hybrid', 'hiace',
#         'highlander', 'highlander hybrid', 'hilux', 'land cruiser',
#         'matrix', 'mirai', 'mr2', 'mr2 spyder', 'paseo', 'previa', 'prius',
#         'prius c', 'prius plug in', 'prius plug in hybrid', 'prius prime',
#         'prius v', 'rav4', 'rav4 hybrid', 'rav4 prime', 'regular cab',
#         'sequoia', 'sienna', 'solara', 'supra', 't100 regular cab',
#         't100 xtracab', 'tacoma', 'tacoma access cab', 'tacoma double cab',
#         'tacoma regular cab', 'tacoma xtracab', 'tercel', 'tundra',
#         'tundra access cab', 'tundra crewmax', 'tundra double cab',
#         'tundra hybrid crewmax', 'tundra regular cab', 'venza', 'xtra cab',
#         'yaris', 'yaris hatchback', 'yaris ia'], dtype='<U23'),
#  'trabant': array(['1 1', '601', 'fourgonette', 'k belwagen', 'limousine', 'nt',
#         'p50', 'p50 coup', 'p50 pickup', 'p60', 'p601z', 'p602v', 'p603',
#         'p610', 'pickup', 'tramp', 'universal'], dtype='<U11'),
#  'triumph': array(['adventurer', 'america', 'america classic', 'bonneville',
#         'bonneville se', 'bonneville steve mcqueen se', 'bonneville t100',
#         'bonneville t100 110th anniversary l', 'bonneville t100 jet black',
#         'daytona 600', 'daytona 675', 'daytona 675 r', 'daytona 955i',
#         'daytona 955i ce', 'legend tt', 'rocket iii', 'rocket iii classic',
#         'rocket iii classic tourer', 'rocket iii roadster',
#         'rocket iii touring', 'scrambler', 'speed four', 'speed triple',
#         'speed triple abs', 'speed triple r abs', 'speed triple se',
#         'speedmaster', 'sprint rs', 'sprint st', 'street triple 675',
#         'street triple r', 'thruxton', 'thruxton se', 'thunderbird',
#         'thunderbird abs', 'thunderbird se', 'thunderbird sport',
#         'thunderbird storm', 'tiger', 'tiger 1050 abs',
#         'tiger 1050 abs se', 'tiger 1050 se', 'tiger 800', 'tiger 800 abs',
#         'tiger 800 xc', 'tiger 800 xc abs', 'tiger explorer',
#         'tiger explorer xc', 'trophy 1200', 'trophy 900', 'trophy se',
#         'tt600'], dtype='<U35'),
#  'ud': array(['1200', '1300', '1400', '1800', '1800cs', '1800hd', '2000', '2300',
#         '2300dh', '2300lp', '2600', '3300'], dtype='<U6'),
#  'vento': array(['phantera', 'phantom r3', 'phantom r4i'], dtype='<U11'),
#  'vespa': array(['gt 200 granturismo', 'gts 250', 'gts 300', 'gts 300 super',
#         'gts 300 super sport se', 'gtv 250', 'gtv 300'], dtype='<U22'),
#  'victory': array(['15th anniversary cross country tour', 'arlen ness vision',
#         'boardwalk', 'classic cruiser', 'cory ness cross country',
#         'cory ness cross country tour', 'cory ness jackpot',
#         'cross country', 'cross country 8 ball', 'cross country tour',
#         'cross roads', 'cross roads 8 ball', 'cross roads classic',
#         'cross roads classic le', 'gunner', 'hammer', 'hammer 8 ball',
#         'hammer s', 'hard ball', 'high ball', 'jackpot', 'judge',
#         'kingpin', 'kingpin 8 ball', 'kingpin low', 'kingpin tour',
#         'ness cross country', 'touring cruiser', 'v92c', 'v92c deluxe',
#         'v92sc', 'v92tc', 'vegas', 'vegas 8 ball', 'vegas jackpot',
#         'vegas low', 'vision 8 ball', 'vision street',
#         'vision street premium', 'vision tour', 'vision tour 10th anniv',
#         'vision tour comfort', 'vision tour premium',
#         'zach ness cross country', 'zach ness vegas'], dtype='<U35'),
#  'vinfast': array(['vf 6', 'vf 7', 'vf 8', 'vf 9'], dtype='<U4'),
#  'volkswagen': array(['amarok', 'arteon', 'atlas', 'atlas cross sport', 'beetle',
#         'beetle cabrio', 'beetle convertible', 'bora', 'cabrio',
#         'cabrio new', 'cabriolet', 'caddy', 'cc', 'clasico', 'combi',
#         'corrado', 'crafter', 'crossfox', 'derby', 'e golf', 'eos',
#         'eurovan', 'fox', 'gli', 'gol', 'gol sedan', 'golf',
#         'golf alltrack', 'golf city', 'golf gti', 'golf iii', 'golf new',
#         'golf r', 'golf sportwagen', 'gti', 'gti new', 'id 4', 'id 7',
#         'id buzz', 'jetta', 'jetta city', 'jetta gli', 'jetta iii',
#         'jetta new', 'jetta sportwagen', 'lupo', 'multivan', 'new beetle',
#         'panel', 'passat', 'passat cc', 'passat new', 'phaeton', 'pickup',
#         'pointer', 'pointer truck', 'polo', 'r32', 'rabbit', 'routan',
#         'saveiro', 'sedan', 'sharan', 'sportvan', 'taos', 'the beetle',
#         'tiguan', 'tiguan limited', 'touareg', 'touareg 2', 'transporter',
#         'van'], dtype='<U18'),
#  'volvo': array(['240', '740', '850', '940', '960', 'c30', 'c40 recharge', 'c70',
#         'ex30', 'ex90', 's40', 's40 new', 's60', 's60 cross country',
#         's70', 's80', 's90', 'v40', 'v40 cross country', 'v50', 'v60',
#         'v60 cross country', 'v70', 'v90', 'v90 cross country', 'xc40',
#         'xc40 recharge', 'xc60', 'xc70', 'xc90'], dtype='<U17'),
#  'vpg': array(['mv 1'], dtype='<U4'),
#  'western rv': array(['alpine'], dtype='<U6'),
#  'western star': array(['3700', '3800'], dtype='<U4'),
#  'workhorse': array(['fastrack ft1061', 'fastrack ft1260', 'fastrack ft1261',
#         'fastrack ft1460', 'fastrack ft1461', 'fastrack ft1600',
#         'fastrack ft1601', 'fastrack ft1800', 'fastrack ft1801',
#         'fastrack ft1802', 'fastrack ft931', 'lf72', 'p30', 'p32', 'p42',
#         'r26', 'r32', 'w16', 'w18', 'w20', 'w21', 'w22', 'w24', 'w25',
#         'w42', 'w62'], dtype='<U15'),
#  'yamaha': array(['br250t bravo', 'br250t bravo lt', 'bws 50', 'cp250 morphous',
#         'cw50 zuma ii', 'cy50 jog', 'fa1800 waverunner fx sho',
#         'fa1800a waverunner fx cruiser sho', 'fb1800 waverunner fx ho',
#         'fb1800a waverunner fx cruiser ho', 'fc1800 fx svho',
#         'fc1800a fx cruiser svho', 'fjr1300', 'fjr1300a abs', 'fjr1300ae',
#         'fjr1300es', 'fx10 fx nytro', 'fx1000 fx140',
#         'fx1000 waverunner fx', 'fx1000a fx140 cruiser',
#         'fx1000a waverunner fx cruiser', 'fx10m fx nytro mtx 153',
#         'fx10m fx nytro mtx 162', 'fx10m fx nytro mtx se 153',
#         'fx10mt fx nytro mtx', 'fx10mtr fx nytro mx',
#         'fx10mtra fx nytro mtx 40th anniv', 'fx10mts fx nytro mtx se 162',
#         'fx10rt fx nytro rtx non reverse', 'fx10rtr fx nytro rtx',
#         'fx10rtra fx nytro rtx 40th anniv', 'fx10rtrs fx nytro rtx se',
#         'fx10xt fx nytro xtx', 'fx10xt fx nytro xtx 1 75',
#         'fx1100 waverunner fx ho', 'fx1100 waverunner vx',
#         'fx1100a waverunner fx cruiser ho',
#         'fx1100b waverunner fx cruiser ho 50',
#         'fx1800 waverunner fx cruiser sho', 'fx1800 waverunner fx sho',
#         'fy1800 waverunner fx ho', 'fy1800a waverunner fx cruiser ho',
#         'fz 09', 'fz6r', 'fz8', 'fzs1000 fz1', 'fzs600 fz6',
#         'gp1200 waverunner gp1200', 'gp1300 waverunner gp1300r',
#         'gp800a waverunner gp800r', 'gx1800 waverunner fzr',
#         'gx1800a waverunner fzs', 'mm600 mountain max 600',
#         'mm700 mountain max 700', 'pw50', 'pw80', 'pz50 phazer',
#         'pz500 phazer 500', 'pz500dx phazer deluxe',
#         'pz500ml phazer mountain lite', 'pz50fx phazer fx',
#         'pz50gt phazer gt', 'pz50mt phazer mountain lite',
#         'pz50mt phazer mtx', 'pz50rtx phazer rtx', 'pz50vt venture lite',
#         'pz50xt phazer xtx', 'rm1800 ar192', 'rm1800 sx192',
#         'rpz50 venture mp', 'rs venture gt', 'rs10 rs venture tf',
#         'rs90 rs vector', 'rs90gt vector gt',
#         'rs90gta rs vector 40th anniv', 'rs90lt rs vector ltx',
#         'rs90ltgt rs vector lt gt', 'rs90ltgt rs vector ltx gt',
#         'rs90m rs vector mountain', 'rs90ms rs vector mountain se',
#         'rs90n nytro', 'rs90nr nytro er', 'rs90r rs vector',
#         'rs90r rs vector er', 'rsg90 rs rage', 'rsg90gt rs rage gt',
#         'rst90 rs venture', 'rst90gt rs venture gt', 'rx10 rx 1',
#         'rx10gt apex gt', 'rx10gta apex gt 40th anniv', 'rx10lt apex ltx',
#         'rx10ltgt apex ltx gt', 'rx10ltgta apex ltx gt 40th anniv',
#         'rx10m apex mountain', 'rx10m rx 1 mountain',
#         'rx10ms apex mountain se', 'rx10ms rx 1 mountain le',
#         'rx10mt apex mtx', 'rx10mta apex mtx se 40th anniv',
#         'rx10ps apex se', 'rx10px apex xtx', 'rx10r apex', 'rx10r apex er',
#         'rx10r rx 1 er', 'rx10rs rx 1 er le', 'rx10rt apex rtx',
#         'rx10rtr apex rtx er', 'rx10s rx 1 le', 'rx1800 ar190',
#         'rx1800 sx190', 'rxw10 attack', 'rxw10 rx warrior',
#         'rxw10gt attack gt', 'rxw10s rx warrior le', 'sh50 razz',
#         'sj700 super jet', 'sr viper', 'sr viper ltx', 'sr viper ltx se',
#         'sr viper rtx se', 'sr viper xtx se', 'sr400', 'srx120 sx120',
#         'srx700', 'srx700s', 'sv1200 waverunner suv1200', 'sx500 r',
#         'sx600 r', 'sx700 r', 'sxt1800 242 limited',
#         'sxt1800 242 limited s', 'sxt1800 ar240 ho', 'sxt1800 sx240 ho',
#         'sxv60 sx venom', 'sxv60er sx venom er', 'sxv700 sx viper',
#         'sxv700er sx viper er', 'sxv70mh sx viper mountain', 'ttr110e',
#         'ttr125', 'ttr125e', 'ttr125l', 'ttr125le', 'ttr225', 'ttr230',
#         'ttr250', 'ttr50e', 'ttr90', 'ttr90e', 'tw200', 'tz250',
#         'vk10 viking professional', 'vk540 iii', 'vmx1200 v max',
#         'vmx1700 v max', 'vt500 venture 500', 'vt500xl venture 500 xl',
#         'vt600 venture 600', 'vt700 venture 700',
#         'vx1100 waverunner 1100 sport', 'vx1100 waverunner vx',
#         'vx1100a waverunner 1100 deluxe', 'vx1100a waverunner vx cruiser',
#         'vx1100b waverunner vx deluxe', 'vx1100c waverunner vx sport',
#         'vx1800ak waverunner vxr', 'vx1800k waverunner vxs',
#         'vx500 vmax 500', 'vx500dx vmax 500 deluxe',
#         'vx600dx vmax 600 deluxe', 'vx600er vmax 600 er', 'vx700 vmax 700',
#         'vx700dx vmax 700 deluxe', 'vx700er vmax 700 er', 'wr250f',
#         'wr250r', 'wr250x', 'wr426f', 'wr450f',
#         'xa1200 waverunner xlt1200', 'xa1200a waverunner xlt1200',
#         'xa800 waverunner xl800', 'xa800a waverunner xlt800',
#         'xat1800 212ss', 'xat1800 212x', 'xc125 riva 125',
#         'xc50 vino 50 classic', 'xf50 c3', 'xl700 waverunner xl700',
#         'xl700a waveventure xl700', 'xp50 c3', 'xp500 tmax', 'xt225',
#         'xt250', 'xtz1200 super tenere', 'xv1600a road star',
#         'xv1600as road star midnight', 'xv1600at road star silverado',
#         'xv1700a road star', 'xv1700am road star midnight',
#         'xv1700as road star s', 'xv1700at road star silverado',
#         'xv1700atm road star midnight silver',
#         'xv1700ats road star silverado s', 'xv1700pc road star warrior',
#         'xv1700pcm road star midnight warrio', 'xv1900 roadliner',
#         'xv1900ct stratoliner', 'xv1900ct stratoliner deluxe',
#         'xv1900ctm stratoliner midnight', 'xv1900cts stratoliner s',
#         'xv1900m roadliner midnight', 'xv1900s roadliner s',
#         'xv19c raider scl', 'xv19cx raider', 'xv19cxc raider s',
#         'xv250 v star 250', 'xv250 virago', 'xvs1100 v star 1100 custom',
#         'xvs1100a v star 1100 classic', 'xvs1100at v star 1100 silverado',
#         'xvs13 stryker', 'xvs1300 v star 1300',
#         'xvs1300 v star 1300 deluxe', 'xvs1300a v star 1300 tourer',
#         'xvs650 v star custom', 'xvs650a v star classic',
#         'xvs650at v star silverado', 'xvs950 bolt', 'xvs950 bolt r spec',
#         'xvs950 v star 950', 'xvs950ct v star 950 tourer',
#         'xvz1300al royal star boulevard',
#         'xvz1300ct royal star tour deluxe',
#         'xvz1300ctm royal star midnight tour',
#         'xvz1300cts royal star tour deluxe s',
#         'xvz1300tf royal star venture',
#         'xvz1300tfm royal star midnight vent',
#         'xvz1300tfs royal star venture s', 'yfa 1 breeze125',
#         'yfm125 grizzly', 'yfm125 raptor', 'yfm250 bear tracker',
#         'yfm250 big bear', 'yfm250 bruin', 'yfm250 raptor',
#         'yfm250 raptor se', 'yfm250 raptor se custom', 'yfm250r raptor',
#         'yfm300 grizzly automatic', 'yfm350 bruin auto 2x4',
#         'yfm350 grizzly 4x4 auto', 'yfm350 grizzly auto',
#         'yfm350 grizzly irs 4x4 auto', 'yfm350 raptor', 'yfm350 wolverine',
#         'yfm350f wolverine 4x4', 'yfm350fa bruin auto 4x4',
#         'yfm350x warrior', 'yfm400 big bear 2x4', 'yfm400 big bear 4x4',
#         'yfm400 big bear irs 4x4', 'yfm400 grizzly 4x4 auto',
#         'yfm400a kodiak', 'yfm400f kodiak 4x4', 'yfm450 grizzly 4x4 auto',
#         'yfm450 grizzly 4x4 auto eps', 'yfm450 grizzly 4x4 auto irs',
#         'yfm450f kodiak auto 4x4', 'yfm450fx wolverine 4x4',
#         'yfm50 raptor', 'yfm550 grizzly fi 4x4 auto',
#         'yfm550 grizzly fi 4x4 auto eps', 'yfm600fw grizzly 4x4',
#         'yfm660f grizzly 4x4', 'yfm660r raptor',
#         'yfm700 grizzly fi 4x4 auto', 'yfm700 grizzly fi 4x4 auto eps',
#         'yfm700 grizzly fi 4x4 auto eps se', 'yfm700 raptor',
#         'yfm700r raptor', 'yfm700r raptor gytr edition',
#         'yfm700r raptor se', 'yfm80 badger', 'yfm80 grizzly',
#         'yfm80w raptor', 'yfm90 raptor', 'yfs200 blaster',
#         'yfz350 banshee', 'yfz450', 'yfz450 bill balance edition',
#         'yfz450 se', 'yfz450r', 'yfz450r se', 'yfz450x',
#         'yfz450x bill balance', 'yfz450x se', 'yj125 vino 125',
#         'yj50 vino', 'yj50ra vino classic', 'yp400 majesty',
#         'yw125 zuma 125', 'yw50 zuma', 'yw50f zuma 50f',
#         'yw50fx zuma 50fx', 'yxm700 viking fi 4x4',
#         'yxm700 viking fi 4x4 eps', 'yxm700 viking fi 4x4 eps se',
#         'yxm700 viking fi 4x4 eps with sunto',
#         'yxm700 viking fi 4x4 with suntop', 'yxp1000a pro hauler 1000',
#         'yxp700a pro hauler 700', 'yxr45f rhino 450',
#         'yxr45f rhino 450 special edition', 'yxr66f rhino 660',
#         'yxr66f rhino 660 ducks unlimited',
#         'yxr66f rhino 660 exploring edition',
#         'yxr66f rhino 660 special edition',
#         'yxr66f rhino 660 sport edition', 'yxr700f rhino 700 fi',
#         'yxr700f rhino 700 fi ducks unlimite',
#         'yxr700f rhino 700 fi special editio',
#         'yxr700f rhino 700 fi sport edition', 'yz125', 'yz250', 'yz250f',
#         'yz426f', 'yz450f', 'yz80', 'yz85', 'yzf r1', 'yzf r1 le',
#         'yzf r6', 'yzf r6s', 'yzf600r'], dtype='<U35')}

# %%
print(df['model'].isnull().sum())
# Out:
# 20481

# %%
df['original_model'] = df['model'].copy()

df['model'] = df.apply(match_model, axis=1)

filled_mask = df['original_model'].isnull() & df['model'].notnull()
unfilled_mask = df['original_model'].isnull() & df['model'].isnull()
filled_df = df[filled_mask][['name', 'model', 'brand']]
unfilled_df = df[unfilled_mask][['name', 'model', 'brand']]

# %%
print(df['model'].isnull().sum())
# Out:
# 7796

# %%
df[df['brand'] == 'sonstige_autos'].count()
# Out:
# index                  3980
# dateCrawled            3980
# name                   3980
# price                  3980
# abtest                 3980
# vehicleType            2917
# yearOfRegistration     3980
# gearbox                2817
# powerPS                3980
# model                     0
# kilometer              3980
# monthOfRegistration    3980
# fuelType               2808
# brand                  3980
# notRepairedDamage      2616
# dateCreated            3980
# postalCode             3980
# lastSeen               3980
# original_model            0
# dtype: int64

# %%
unfilled_df
# Out:
#                                                      name model  \
# 60      TAUSCHE_BMW_E38_740i_g._SUV_/_GELÄNDEWAGEN_LES...  None
# 83                         Bastler_Fahrzeug_mit_Rest_Tuev  None
# 165                                            is_ales_ok  None
# 318                       Tauache_90ccm_roller_gegen_auto  None
# 376                                          Corvette_Z06  None
# ...                                                   ...   ...
# 371226                       Suche_Transporter_oder_caddy  None
# 371309     Tausche_Golf2_gegen_VW_Audi_oder_Ratte_Ratlook  None
# 371476                                  ALPINA_D3_Touring  None
# 371509  LT_35_DIESEL_Gruene_Plakette....letzte_Gelegen...  None
# 371523                         Suche_t4___vito_ab_6_sitze  None
#
#                  brand
# 60      sonstige_autos
# 83                fiat
# 165            renault
# 318     sonstige_autos
# 376     sonstige_autos
# ...                ...
# 371226  sonstige_autos
# 371309      volkswagen
# 371476  sonstige_autos
# 371509      volkswagen
# 371523  sonstige_autos
#
# [7796 rows x 3 columns]

# %%
filled_df
# Out:
#                                               name  model       brand
# 1                             A5_Sportback_2.7_Tdi     a5        audi
# 119                 Polo_6n_Karosse_zu_verschenken   polo  volkswagen
# 139        Audi_80_5_Zylinder_b4_liebhaberfahrzeug     80        audi
# 156                        POLO_1.2_KILIMA_WIE_NEU   polo  volkswagen
# 166                         VW_Caddy_Lkw_Zulassung  caddy  volkswagen
# ...                                            ...    ...         ...
# 371220           VW_Polo_6n_fuer_Bastler_abzugeben   polo  volkswagen
# 371223                     Handa_Jazz__top_Zustand   jazz       honda
# 371388                              Audi_A4_2.4_v6     a4        audi
# 371399  Fiat_Stilo_Abarth_2.4_5zylinder_Seelespeed  stilo        fiat
# 371495                                  Opel_Tigra  tigra        opel
#
# [12685 rows x 3 columns]

# %%
df.drop(columns=['original_model'], inplace=True)

# %% [markdown]
# ## Target Variable Analysis (`price`)
#
# The dataset contains the price of the car (`price`) as the primary target variable. We can perform the following tasks as part of the EDA:
#
# * Distribution of `price`:
#     * Plot a histogram or density plot to observe the price distribution.
#     * Check for normality, skewness and outliers.
# * Bin `price` into categories:
#     * Create categories like "Low," "Average," and "High" price to analyze patterns.

# %%
# distribution
# `price` has extreme values that make rendering the histogram impossible
# thus, we exclude them just for the chart
q_low, q_high = df['price'].quantile([0.001, 0.999])
df_trimmed = df[(df['price'] >= q_low) & (df['price'] <= q_high)]

fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(df_trimmed['price'], kde=True)
ax.set_title("Distribution of Car Price (Price)")
ax.set_xlabel("Price")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# The target variable involves a large amount of outliers. Extreme outliers. This visual observation is confirmed by the following boxplot:

# %%
# boxplot
fig, ax = plt.subplots(figsize=(20,10))
sns.boxplot(data=df, y='price')
# Out:
# <Axes: ylabel='price'>

# %%
# boxplot
fig, ax = plt.subplots(figsize=(20,10))
sns.boxplot(data=df_trimmed, y='price')
# Out:
# <Axes: ylabel='price'>

# %%
q_low, q_high = df['price'].quantile([0.15, 0.85])
df_trimmed = df[(df['price'] >= q_low) & (df['price'] <= q_high)]

fig, ax = plt.subplots(figsize=(20,10))
sns.boxplot(data=df_trimmed, y='price')
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# The target variable can be said that it does not follow the normal distribution based on the output of the normality tests shown below. All of them are

# %%
def run_normality_tests(data):
    """
    Perform various normality tests (Shapiro-Wilk, Anderson-Darling, Kolmogorov-Smirnov, D'Agostino and Pearson, Jarque-Bera, and Lilliefors) on a given dataset.
    Choosing the Right Test:
        * For small sample sizes (< 50), the Shapiro-Wilk Test is recommended.
        * For larger samples, use the D’Agostino and Pearson’s Test or Jarque-Bera Test.
        * If you need critical values, use the Anderson-Darling Test.
        * Use the Kolmogorov-Smirnov Test or Lilliefors Test for additional validation, especially when comparing with a reference distribution.
    
    All tests compute a p-value. The p-value (probability value) is a statistical measure that helps you determine whether the observed data is consistent with a 
    null hypothesis. In the context of normality tests, the null hypothesis is usually: "The data follows a normal distribution."
    
    How to Interpret the p-value:
        * High p-value (>= 0.05): There is not enough evidence to reject the null hypothesis. This suggests that the data might follow a normal distribution.
        * Low p-value (< 0.05): The null hypothesis is rejected. This indicates that the data does not follow a normal distribution.
        
    In Practice
        * If a test returns a p-value of 0.03, it means there is a 3% probability that the data could have arisen under the assumption of a normal distribution. In this case, you would reject the null hypothesis (assuming a 5% significance threshold).
        * If a test returns a p-value of 0.2, it suggests there is no strong evidence against the data being normal.

    Caveats
        * A high p-value does not prove normality, it simply suggests that the data is not inconsistent with a normal distribution.
        * A low p-value indicates a deviation from normality but does not specify the nature of that deviation (e.g., skewness, kurtosis).

    Parameters:
        data (array-like): The dataset to test for normality.

    Returns:
        dict: A dictionary containing test results with the test name, statistic, p-value, and whether the data is considered normal at a 5% significance level.
    """
    results = {}

    # Shapiro-Wilk Test
    # this test is commented out since it provides unreliable results for N > 5000
    """
    try:
        stat, p = shapiro(data)
        results['Shapiro-Wilk Test'] = {'Statistic': stat, 'p-value': p, 'Normal': p > 0.05}
    except Exception as e:
        results['Shapiro-Wilk Test'] = {'Error': str(e)}
    """

    # Anderson-Darling Test
    try:
        result = anderson(data, dist='norm')
        results['Anderson-Darling Test'] = {
            'Statistic': result.statistic,
            'Critical Values': result.critical_values,
            'Significance Levels': result.significance_level,
            'Normal': result.statistic < result.critical_values[2]  # At 5% level
        }
    except Exception as e:
        results['Anderson-Darling Test'] = {'Error': str(e)}

    # Kolmogorov-Smirnov Test
    try:
        standardized_data = (data - np.mean(data)) / np.std(data)
        stat, p = kstest(standardized_data, 'norm')
        results['Kolmogorov-Smirnov Test'] = {'Statistic': stat, 'p-value': p, 'Normal': p > 0.05}
    except Exception as e:
        results['Kolmogorov-Smirnov Test'] = {'Error': str(e)}

    # D’Agostino and Pearson’s Test
    try:
        stat, p = normaltest(data)
        results['D’Agostino and Pearson’s Test'] = {'Statistic': stat, 'p-value': p, 'Normal': p > 0.05}
    except Exception as e:
        results['D’Agostino and Pearson’s Test'] = {'Error': str(e)}

    # Jarque-Bera Test
    try:
        stat, p = jarque_bera(data)
        results['Jarque-Bera Test'] = {'Statistic': stat, 'p-value': p, 'Normal': p > 0.05}
    except Exception as e:
        results['Jarque-Bera Test'] = {'Error': str(e)}

    # Lilliefors Test
    try:
        stat, p = lilliefors(data)
        results['Lilliefors Test'] = {'Statistic': stat, 'p-value': p, 'Normal': p > 0.05}
    except Exception as e:
        results['Lilliefors Test'] = {'Error': str(e)}

    return results

# %%
results = run_normality_tests(df['price'])
for test, result in results.items():
    print(f"{test}: {result}")
# Out:
# Anderson-Darling Test: {'Statistic': 142863.78784574172, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.49807694595155544, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 2413270.2645356734, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 1846925273351852.8, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.4980769485396755, 'p-value': 0.0009999999999998899, 'Normal': False}

# %% [markdown]
# From the aforementioned resuts, **price deviates from normality**.

# %% [markdown]
# From the histogram and the kernel density estimate (KDE) curve shown above, we can say that the distribution appears to be very asymmetric around its left peak, which is approximately 0-2000. There is an extreme tail elongation on the right side. Since the distribution is approximately asymmetric, it suggests that the skewness value would be large. However, the exact skewness value would need to be calculated. Below, we are using the .skew() function to reveal if the target variable is skewed:
#
# * If the skewness is between -0.5 and 0.5, the data are fairly symmetrical
# * If the skewness is between -1 and -0.5 or between 0.5 and 1, the data are moderately left-skewed or right-skewed respectively
# * If the skewness is less than -1 or greater than 1, the data are highly left-skewed or right-skewed respectively

# %%
print('skewness:', df['price'].skew())
# Out:
# skewness: 578.0474145827042

# %% [markdown]
# As show above, the **target variable is extremely right-skewed**, therefore unskewing techniques such as Log, Sqrt, Box-Cox and Yeo-Johnson can be applied. Since `price` consists only of positive values, we can use every technique mentioned.

# %% [markdown]
# ### Predicting values more than 200,000 and below 1,000 is not useful.
# ### In order to make our model effectively predict prices 1,000 - 200,000 we will exclude all rows with prices outside this range.

# %%
print(df.shape)
df = df.drop(df[(df['price'] < 1000) | (df['price'] > 200_000)].index, axis='index')
print(df.shape)
# Out:
# (371513, 18)
# (288017, 18)

# %%
df.describe()
# Out:
#                index          price  yearOfRegistration        powerPS  \
# count  288017.000000  288017.000000       288017.000000  288017.000000
# mean   185822.266804    7190.014364         2005.126315     127.638504
# std    107308.453298    8769.154698           63.813781     194.191270
# min         1.000000    1000.000000         1000.000000       0.000000
# 25%     92839.000000    2200.000000         2001.000000      80.000000
# 50%    185862.000000    4350.000000         2005.000000     116.000000
# 75%    278859.000000    8950.000000         2009.000000     160.000000
# max    371527.000000  200000.000000         9999.000000   20000.000000
#
#            kilometer  monthOfRegistration     postalCode
# count  288017.000000        288017.000000  288017.000000
# mean   122733.866404             6.024148   51650.045171
# std     40790.242233             3.591257   25701.406282
# min      5000.000000             0.000000    1067.000000
# 25%    100000.000000             3.000000   31226.000000
# 50%    150000.000000             6.000000   50769.000000
# 75%    150000.000000             9.000000   72469.000000
# max    150000.000000            12.000000   99998.000000

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(df['price'], kde=True)
ax.set_title("Distribution of Car Price (Price)")
ax.set_xlabel("Price")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# boxplot
fig, ax = plt.subplots(figsize=(20,10))
sns.boxplot(data=df, y='price')
# Out:
# <Axes: ylabel='price'>

# %%
q_low, q_high = df['price'].quantile([0.1, 0.9])
df_trimmed = df[(df['price'] >= q_low) & (df['price'] <= q_high)]

fig, ax = plt.subplots(figsize=(20,10))
sns.boxplot(data=df_trimmed, y='price')
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# Dominant bin is low, meaning our model will perform better on cars with lower prices, also decent on average prices. Since we have very few high instances, our model will sruggle for such prices

# %% [markdown]
# ## Categorical Features Analysis

# %%
categorical_features = ['abtest', 'vehicleType', 'gearbox', 'monthOfRegistration', 'fuelType', 'notRepairedDamage']
nrows, ncols = 3, 2
fig, axs = plt.subplots(nrows, ncols, figsize=(18,21))
i,j = 0,0
for feature in categorical_features:
    sns.countplot(x=feature, data=df, ax=axs[i,j])
    axs[i,j].set_title(f"Distribution of {feature}")
    j = j + 1
    if j % ncols == 0:
        i = i + 1
        j = 0

# %% [markdown]
# The bar plots shown above depict the distributions of several categorical variables in the dataset. Here are observations and insights for each feature:
#
# 1. ABtest (abtest)
#    * both values (test and control) have similar distributions, while test appears more often
#    * this variable can be useful for understanding the role of ABtest on price
# 2. Vehicle type (vehicleType)
#    * three of the vehicle types dominate the distribution (kleinwagen, limousine, kombi)
#    * the rest appear often enough to matter
#    * andere appears too few times, perhaps oversampling could be used
# 3. gearbox (gearbox)
#    * the majority of gearbox values are manual (manuell), though a signifigant portion is automatic (automatik)
#    * the value of gearbox could help play a major role in determining the value of price
# 4. month of registration (monthOfRegistration)
#    * each month has more or less similar amount of car registrations
#    * months have 13th value, maybe 0 value is for null/NaN (dataset documentation does not specify)
# 5. fuel type (fuelType)
#    * benzin appears, by far, the most often
#    * desel appears often enough to impact learning
#    * the rest of the values (lpg, andere, hybrid, cng, elektro) are extremely rare, perhaps we should join all these values into an `other` category
# 6. not repaired damage (notRepairedDamage)
#    * nein dominates as a value
#    * ja does appear, though maybe not enough
#    * this could impact training

# %%
# model brand
nrows, ncols = 2, 1
fig, axs = plt.subplots(nrows, ncols, figsize=(20, 10))

# Plot model distribution
sns.countplot(x='model', data=df, ax=axs[0])
axs[0].set_title("Distribution of Model")
axs[0].tick_params(axis='x', rotation=90)
axs[0].set_xticklabels([])

sns.countplot(x='brand', data=df, ax=axs[1])
axs[1].set_title("Distribution of Brand")
axs[1].tick_params(axis='x', rotation=90)

# %%
# Count how many times each model appears
model_counts = df['model'].value_counts()

# Determine quantile thresholds
q_low, q_high = model_counts.quantile([0.35, 0.65])

# Keep models within those frequency bounds
valid_models = model_counts[(model_counts >= q_low) & (model_counts <= q_high)].index

# Filter the DataFrame
df_trimmed = df[df['model'].isin(valid_models)]

# Plotting
nrows = 1
fig, axs = plt.subplots(nrows, ncols, figsize=(20, 10))

# Model plot
sns.countplot(x='model', data=df_trimmed)
axs.set_title("Distribution of Model (Trimmed)")
axs.tick_params(axis='x', rotation=90)

# %% [markdown]
# # TODO: What about NAME?

# %% [markdown]
# # TODO: how should we handle model, name, barnd?

# %% [markdown]
# #### General observations:
# * Features like vehicleType, gearbox, fuelType and notRepairedDamage have unbalanced distributions, we should consider using stratified sampling during data splitting for more fair comparisons
# * Use grouped bar plots to better visualize the relationship between categorical features (since we cannot apply heatmap method)
# * Search for correlation between features and target by comparing distributions with the 'cetegorical' version of out target (via binning method)

# %%
# Barplots: Visualize statistical measures (mean, std, median) of price for each category of a categorical variable.
categorical_features = ['abtest', 'vehicleType', 'gearbox', 'monthOfRegistration', 'fuelType', 'notRepairedDamage']
nrows, ncols = 3, 2
fig, axs = plt.subplots(nrows, ncols, figsize=(18,21))
i,j = 0,0
for feature in categorical_features:
    sns.barplot(y='price', x=feature, data=df, ax=axs[i,j])
    axs[i,j].set_title(f"price mean and std by {feature}")
    j = j + 1
    if j % ncols == 0:
        i = i + 1
        j = 0

# %% [markdown]
# 1. abtest (abtest)
#    * either category of abtest seems to have no influence over the price, since the mean depending on each category is the same of that of price.
#    * meaning, this feature has no correlation with the target
#    * perhaps we should remove this feature as it may have no influence on the target
# 2. type of vehicle (vehicleType)
#    * each category plays a role in the value of price with rather small deviation
#    * we can assume a large correlation between vehicle type and price
# 3. gearbox (gearbox)
#    * the category of gearbox matters significantly to the price value
#    * very high correlation with target
# 4. month of registration (monthOfRegistration)
#    * all months except '0' have similar mean price. We need to investigate further into why '0' has different mean...
# 5. type of fuel (fuelType)
#    * very clearly the type of fuel has high correlation, since price values vary a lot by type.
#    * we cannot condense hybrid and elektro into 'other' category, since the value of price changes significantly for those values.
#    * is hybrid and elektro a value we wish to keep? maybe we should discard them alltogether
#    * lpg andere and cng could be condensed into 'other'
# 6. not repaired damge (notRepairedDamage)
#    * this is another feature with high correlation since there's a huge difference in value depending on the category
#
# #### General observations:
# * all of the correlations found make a lot of sense
# * except for month...

# %%
# Barplots: Visualize statistical measures (mean, std, median) of price for each category of a categorical variable.
categorical_features = ['abtest', 'vehicleType', 'gearbox', 'monthOfRegistration', 'fuelType', 'notRepairedDamage']
nrows, ncols = 3, 2
fig, axs = plt.subplots(nrows, ncols, figsize=(18,21))
i,j = 0,0
for feature in categorical_features:
    sns.boxplot(y='price', x=feature, data=df, ax=axs[i,j])
    axs[i,j].set_title(f"price distribution by {feature}")
    j = j + 1
    if j % ncols == 0:
        i = i + 1
        j = 0

# %% [markdown]
# * From the above boxplots, we observe similar behaviours as the barplots.
# * We should note, that every category value has a large amount of outliers

# %% [markdown]
# # We do the same for brand and model:

# %%
# model brand
nrows, ncols = 2, 1
fig, axs = plt.subplots(nrows, ncols, figsize=(18,21))

# Plot model distribution
sns.barplot(y='price', x='model', data=df, ax=axs[0])
axs[0].set_title("price mean and std by model")
axs[0].tick_params(axis='x', rotation=90)
axs[0].set_xticklabels([])

sns.barplot(y='price', x='brand', data=df, ax=axs[1])
axs[1].set_title("price mean and std by brand")
axs[1].tick_params(axis='x', rotation=90)

# %%
# model brand
nrows, ncols = 2, 1
fig, axs = plt.subplots(nrows, ncols, figsize=(18,21))

# plot model distribution
sns.barplot(y='price', x='model', data=df, ax=axs[0])
axs[0].set_title("price mean and std by model")
axs[0].tick_params(axis='x', rotation=90)
axs[0].set_xticklabels([])

# plot brand distribution
sns.barplot(y='price', x='brand', data=df, ax=axs[1])
axs[1].set_title("price mean and std by brand")
axs[1].tick_params(axis='x', rotation=90)

# %%
# model brand
nrows, ncols = 2, 1
fig, axs = plt.subplots(nrows, ncols, figsize=(18,21))

# plot model distribution
sns.boxplot(y='price', x='model', data=df, ax=axs[0])
axs[0].set_title("price distribution by model")
axs[0].tick_params(axis='x', rotation=90)
axs[0].set_xticklabels([])

# plot brand distribution
sns.boxplot(y='price', x='brand', data=df, ax=axs[1])
axs[1].set_title("price distribution by brand")
axs[1].tick_params(axis='x', rotation=90)

# %%
# Count how many times each model appears
model_counts = df['model'].value_counts()

# Determine quantile thresholds
q_low, q_high = model_counts.quantile([0.22, 0.78])

# Keep models within those frequency bounds
valid_models = model_counts[(model_counts >= q_low) & (model_counts <= q_high)].index

# Filter the DataFrame
df_trimmed = df[df['model'].isin(valid_models)]

# Plotting
nrows, ncols = 1, 1
fig, axs = plt.subplots(nrows, ncols, figsize=(20, 10))

# Model plot
sns.barplot(y='price', x='model', data=df_trimmed)
axs.set_title("price distribution by model (Trimmed)")
axs.tick_params(axis='x', rotation=90)

# %%
# Count how many times each model appears
model_counts = df['model'].value_counts()

# Determine quantile thresholds
q_low, q_high = model_counts.quantile([0.22, 0.78])

# Keep models within those frequency bounds
valid_models = model_counts[(model_counts >= q_low) & (model_counts <= q_high)].index

# Filter the DataFrame
df_trimmed = df[df['model'].isin(valid_models)]

# Plotting
nrows, ncols = 1, 1
fig, axs = plt.subplots(nrows, ncols, figsize=(20, 10))

# Model plot
sns.boxplot(y='price', x='model', data=df_trimmed)
axs.set_title("price distribution by model (Trimmed)")
axs.tick_params(axis='x', rotation=90)

# %% [markdown]
# * model:
#    * we can see very clearly that there's a high correlation between model and price
#    * for most values, there's high deviation
#    * different models within the same brand vary in price, for example 911 and cayenne are both porsche
# * brand:
#    * we can see very clearly that there's a high correlation between brand and price
#    * most brands have low deviation except for a few... this needs more investigation
#
# #### General observations:
# * perhaps the reason behind each deviation of a brand, is in it's various models
# * a car of the same model might have not repaired damage, might be older, or vary in any of the rest features that have a correlation to price
# * each brand or model has outliers, some more than others

# %%
categorical_features = ['abtest', 'vehicleType', 'gearbox', 'monthOfRegistration', 'fuelType', 'notRepairedDamage', 'brand', 'model']
for feature in categorical_features:
    print(df.groupby(feature)['price'].agg(['mean', 'std', 'median']))
    print(df.groupby(feature)['price'].count())
    print('='*60)
# Out:
#                 mean          std  median
# abtest
# control  7172.128118  8673.668750  4350.0
# test     7206.628830  8856.925719  4350.0
# abtest
# control    138700
# test       149317
# Name: price, dtype: int64
# ============================================================
#                      mean           std   median
# vehicleType
# andere        5471.232106   6046.648073   3500.0
# bus           7235.801488   7073.876814   4990.0
# cabrio       11042.387775  13759.333131   6950.0
# coupe        12632.092857  17092.246038   6999.0
# kleinwagen    3943.455187   3475.049264   2799.0
# kombi         6810.304184   6574.001022   4500.0
# limousine     7002.402649   7400.384565   4490.0
# suv          13567.219032  11297.219903  10999.0
# vehicleType
# andere         2417
# bus           27419
# cabrio        21399
# coupe         16197
# kleinwagen    51570
# kombi         55588
# limousine     78602
# suv           14176
# Name: price, dtype: int64
# ============================================================
#                    mean           std  median
# gearbox
# automatik  11403.314337  11909.414931  7900.0
# manuell     5869.998713   6832.713627  3800.0
# gearbox
# automatik     70030
# manuell      207460
# Name: price, dtype: int64
# ============================================================
#                             mean           std  median
# monthOfRegistration
# 0                    4144.360620   6067.391009  2500.0
# 1                    7667.152141   9309.887261  4590.0
# 2                    7426.703391   9313.182696  4500.0
# 3                    7353.112316   9290.264296  4450.0
# 4                    7595.714839   9177.671525  4700.0
# 5                    7266.144314   8844.525520  4455.0
# 6                    7413.675632   9031.364493  4500.0
# 7                    7922.753741  10037.583377  4699.0
# 8                    7130.193170   8117.438207  4490.0
# 9                    7404.859479   8622.226745  4699.0
# 10                   7189.368657   8369.187385  4500.0
# 11                   7333.438316   8140.317658  4500.0
# 12                   6944.037256   7687.802635  4450.0
# monthOfRegistration
# 0     17933
# 1     19403
# 2     17781
# 3     28856
# 4     24800
# 5     24606
# 6     26843
# 7     23524
# 8     19356
# 9     20673
# 10    22506
# 11    21229
# 12    20507
# Name: price, dtype: int64
# ============================================================
#                   mean           std   median
# fuelType
# andere     6463.575758  11920.986696   3000.0
# benzin     6380.997267   9039.428113   3598.0
# cng        5163.007828   3716.087526   4450.0
# diesel     8969.940345   8253.943365   6400.0
# elektro   18353.956044  31925.978065   7000.0
# hybrid    14415.569767  13215.190941  11945.0
# lpg        4981.964958   4344.843694   3525.0
# fuelType
# andere         99
# benzin     163532
# cng           511
# diesel     101181
# elektro        91
# hybrid        258
# lpg          4566
# Name: price, dtype: int64
# ============================================================
#                           mean          std  median
# notRepairedDamage
# ja                 3934.627410  4904.621439  2499.0
# nein               7894.830351  9288.038372  4998.0
# notRepairedDamage
# ja       17169
# nein    228177
# Name: price, dtype: int64
# ============================================================
#                         mean           std   median
# brand
# alfa_romeo       5330.791643   5833.620627   3500.0
# audi             9904.861741   9556.822455   6999.0
# bmw              9111.046028   8767.087827   6650.0
# chevrolet        7527.647653   7735.393150   5000.0
# chrysler         5166.696143   4716.640455   3490.0
# citroen          4563.662623   3916.280756   3200.0
# dacia            6012.284404   3621.215393   4999.5
# daewoo           1546.325581    505.850421   1400.0
# daihatsu         2920.130653   2014.678965   2270.0
# fiat             4085.260983   3538.667747   2999.0
# ford             5174.260362   5665.899699   3000.0
# honda            4983.336372   4340.085992   3625.0
# hyundai          6257.530093   5009.101773   4850.0
# jaguar          13873.000000  19731.911670   6750.0
# jeep            11306.105469  10171.074568   7500.0
# kia              6580.590111   5817.409204   4600.0
# lada             3694.709497   2139.306092   3100.0
# lancia           5360.984848   7752.447193   2825.0
# land_rover      17080.779548  16122.970509  12700.0
# mazda            5145.005252   4754.968180   3650.0
# mercedes_benz    9098.199899  10219.358590   5800.0
# mini            10038.627404   5660.161505   8699.5
# mitsubishi       4930.050314   5731.532723   3250.0
# nissan           6322.108233   6203.114431   3850.0
# opel             4176.902674   3861.587045   2899.0
# peugeot          4044.159322   3362.637930   2999.0
# porsche         39924.015318  32455.944045  30900.0
# renault          3505.597062   3662.899213   2300.0
# rover            2705.297297   3577.366102   1675.0
# saab             4894.643216   4307.688055   3472.5
# seat             5677.765281   5346.753848   4111.0
# skoda            6883.524220   5646.203894   5400.0
# smart            3837.686159   3139.531364   3150.0
# sonstige_autos  15685.652083  23230.890400   8000.0
# subaru           6351.176353   6302.806804   4200.0
# suzuki           5027.511891   4358.101463   3999.5
# toyota           5746.405015   5554.143782   4500.0
# trabant          3076.178832   2240.259556   2490.0
# volkswagen       6498.957048   6504.754219   4200.0
# volvo            6614.635703   6598.604887   4200.0
# brand
# alfa_romeo         1747
# audi              28707
# bmw               35587
# chevrolet          1683
# chrysler           1063
# citroen            3957
# dacia               872
# daewoo              258
# daihatsu            398
# fiat               6123
# ford              16719
# honda              2084
# hyundai            3107
# jaguar              586
# jeep                768
# kia                2164
# lada                179
# lancia              264
# land_rover          753
# mazda              4189
# mercedes_benz     31801
# mini               3328
# mitsubishi         1908
# nissan             3474
# opel              25471
# peugeot            8260
# porsche            2089
# renault           10890
# rover               222
# saab                398
# seat               5219
# skoda              5223
# smart              4754
# sonstige_autos     2857
# subaru              499
# suzuki             1766
# toyota             4227
# trabant             274
# volkswagen        61673
# volvo              2476
# Name: price, dtype: int64
# ============================================================
#                     mean           std   median
# model
# 1 1          3700.000000           NaN   3700.0
# 1 series m   7116.333333   6887.492311   5399.0
# 100          2659.992063   2097.877666   1999.0
# 106          1412.500000    843.457441   1100.0
# 107          3381.928571   1079.691228   3125.0
# ...                  ...           ...      ...
# ypsilon      2488.846154   1727.193864   1699.0
# z3           5683.333333   4405.640324   5000.0
# z4          20712.250000  11424.787390  17749.5
# z_reihe     14167.181714  12493.162180  10998.0
# zafira       4000.881717   2785.852777   3150.0
#
# [668 rows x 3 columns]
# model
# 1 1              1
# 1 series m       3
# 100            252
# 106             12
# 107             14
#               ...
# ypsilon         91
# z3               6
# z4               4
# z_reihe        875
# zafira        2866
# Name: price, Length: 668, dtype: int64
# ============================================================

# %%
bins_df = df.copy()
bins_df['price_category'] = pd.cut(df['price'], bins=[0, 5000, 10_000, 50_000, np.inf], labels=["low", "low average", "middle average", "high"])
bins_df.head()
# Out:
#    index          dateCrawled                            name  price abtest  \
# 1      1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  18300   test
# 2      2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"   9800   test
# 3      3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER   1500   test
# 4      4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic   3600   test
# 6      6  2016-04-01 20:48:51     Peugeot_206_CC_110_Platinum   2200   test
#
#   vehicleType  yearOfRegistration    gearbox  powerPS    model  kilometer  \
# 1       coupe                2011    manuell      190       a5     125000
# 2         suv                2004  automatik      163    grand     125000
# 3  kleinwagen                2001    manuell       75     golf     150000
# 4  kleinwagen                2008    manuell       69    fabia      90000
# 6      cabrio                2004    manuell      109  2_reihe     150000
#
#    monthOfRegistration fuelType       brand notRepairedDamage  \
# 1                    5   diesel        audi                ja
# 2                    8   diesel        jeep               NaN
# 3                    6   benzin  volkswagen              nein
# 4                    7   diesel       skoda              nein
# 6                    8   benzin     peugeot              nein
#
#            dateCreated  postalCode             lastSeen  price_category
# 1  2016-03-24 00:00:00       66954  2016-04-07 01:46:50  middle average
# 2  2016-03-14 00:00:00       90480  2016-04-05 12:47:46     low average
# 3  2016-03-17 00:00:00       91074  2016-03-17 17:40:17             low
# 4  2016-03-31 00:00:00       60437  2016-04-06 10:17:21             low
# 6  2016-04-01 00:00:00       67112  2016-04-05 18:18:39             low

# %%
# distribution
fig, ax = plt.subplots(figsize=(20,10))
sns.countplot(data=bins_df, x="price_category")
ax.set_title("Distribution of Car Price into categories (Price)")
ax.set_xlabel("Price")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Dominant bin is low, meaning our model will perform better on cars with lower prices, also decent on average prices. Since we have very few high instances, our model will sruggle for such prices

# %%
categorical_features = ['abtest', 'vehicleType', 'gearbox', 'monthOfRegistration', 'fuelType', 'notRepairedDamage']
nrows, ncols = 3, 2
fig, axs = plt.subplots(nrows, ncols, figsize=(18,21))
i, j = 0, 0
for feature in categorical_features:
    sns.countplot(x='price_category', hue=feature, data=bins_df, ax=axs[i,j])
    axs[i,j].set_title(f"price categories by {feature}")
    j = j + 1
    if j % ncols == 0:
        i = i + 1
        j = 0

# %% [markdown]
# ## Numerical Features Analysis

# %%
numerical_features = ['yearOfRegistration', 'powerPS', 'kilometer', 'postalCode']
nrows,ncols = 2,2
fig, axs = plt.subplots(nrows, ncols, figsize=(18,21))
i,j = 0,0
for feature in numerical_features:
    sns.histplot(df[feature], kde=True, ax=axs[i,j])
    axs[i,j].set_title(f"Distribution of {feature}")
    j = j + 1
    if j % ncols == 0:
        i = i + 1
        j = 0

# %%
# all yearOfRegistration values less than 1920 are invalid (we have checked one by one)
# all values that we have checked over 1920 seem valid
tmp = df[(df['yearOfRegistration'] < 1940) & (df['yearOfRegistration'] > 1920)]
tmp
# Out:
#          index          dateCrawled  \
# 2376      2376  2016-03-15 21:44:32
# 10549    10549  2016-03-17 20:43:12
# 12468    12468  2016-03-22 10:50:14
# 17320    17320  2016-03-07 13:44:34
# 23714    23714  2016-03-23 11:37:57
# ...        ...                  ...
# 340960  340960  2016-03-20 18:42:40
# 351845  351845  2016-03-27 12:44:33
# 352421  352421  2016-03-11 11:51:33
# 354533  354533  2016-03-05 17:45:32
# 370654  370654  2016-03-16 21:56:55
#
#                                                      name  price   abtest  \
# 2376                                        Andere_Andere   1800  control
# 10549          Ford_V8_Cabrio_im_restaurierten_Topzustand  35000  control
# 12468                Opel_Olympia_Cabrio_1936_Top_Zustand  21900  control
# 17320   Andere_Adler_Trumpf_1_7_AV___sehr_selten__top_...  32000  control
# 23714                       Oldtimer_Citroën_F_AC_4_Bj_29  14000     test
# ...                                                   ...    ...      ...
# 340960                 Chevrolet_Holden_Vorkriegsfahrzeug  24500     test
# 351845                            Opel_kadett_po_renovaci   9000     test
# 352421                                  BMW_DIXI_OLDTIMER  20000  control
# 354533            Ford_Business_Coupe_Hotrod_Projekt.1937   7000     test
# 370654               Mercedes_Benz_170V___Vorkriegsmodell   6000  control
#
#        vehicleType  yearOfRegistration  gearbox  powerPS   model  kilometer  \
# 2376        cabrio                1925      NaN        0    None       5000
# 10549       cabrio                1937  manuell       90  andere       5000
# 12468       cabrio                1936  manuell       23  andere       5000
# 17320    limousine                1933  manuell       38    None       5000
# 23714    limousine                1929  manuell       30    None       5000
# ...            ...                 ...      ...      ...     ...        ...
# 340960      cabrio                1935      NaN        0  andere       5000
# 351845   limousine                1938  manuell        1  kadett       5000
# 352421       coupe                1929  manuell       12  andere      10000
# 354533       coupe                1937  manuell       85  andere       5000
# 370654   limousine                1937  manuell       38  andere       5000
#
#         monthOfRegistration fuelType           brand notRepairedDamage  \
# 2376                      1      NaN  sonstige_autos              nein
# 10549                     6   benzin            ford              nein
# 12468                     7   benzin            opel              nein
# 17320                     7   benzin  sonstige_autos              nein
# 23714                     7   benzin  sonstige_autos               NaN
# ...                     ...      ...             ...               ...
# 340960                    5      NaN       chevrolet              nein
# 351845                    0   benzin            opel               NaN
# 352421                    4   benzin             bmw               NaN
# 354533                    8   benzin            ford                ja
# 370654                    0   benzin   mercedes_benz               NaN
#
#                 dateCreated  postalCode             lastSeen
# 2376    2016-03-15 00:00:00       79288  2016-04-07 05:15:34
# 10549   2016-03-17 00:00:00       50859  2016-04-07 09:15:29
# 12468   2016-03-22 00:00:00       78467  2016-04-05 22:44:48
# 17320   2016-03-07 00:00:00       17109  2016-04-06 03:45:49
# 23714   2016-03-23 00:00:00       90475  2016-04-05 11:18:18
# ...                     ...         ...                  ...
# 340960  2016-03-20 00:00:00       44229  2016-04-07 01:46:40
# 351845  2016-03-27 00:00:00       93437  2016-03-27 12:44:33
# 352421  2016-03-11 00:00:00       74523  2016-04-07 05:45:00
# 354533  2016-03-05 00:00:00        8359  2016-04-07 10:44:39
# 370654  2016-03-16 00:00:00       23936  2016-03-30 18:47:41
#
# [70 rows x 18 columns]

# %%
# For Valid year of registration
df_valid_yearOfRegistration = df[(df['yearOfRegistration'] >= 1920) & (df['yearOfRegistration'] <= 2025)]
nrows,ncols = 1,1
fig, axs = plt.subplots(nrows, ncols, figsize=(20,10))

sns.histplot(df_valid_yearOfRegistration['yearOfRegistration'], kde=True)
axs.set_title(f"Distribution of yearOfRegistration")
# Out:
# Text(0.5, 1.0, 'Distribution of yearOfRegistration')

# %%
# Do not anything before split
df["yearOfRegistration"].sort_values(ascending=True).head(n=20)
df[(df["yearOfRegistration"] < 1920) | (df["yearOfRegistration"] > 2025)].count()
# Out:
# index                  82
# dateCrawled            82
# name                   82
# price                  82
# abtest                 82
# vehicleType             4
# yearOfRegistration     82
# gearbox                27
# powerPS                82
# model                  53
# kilometer              82
# monthOfRegistration    82
# fuelType               30
# brand                  82
# notRepairedDamage      11
# dateCreated            82
# postalCode             82
# lastSeen               82
# dtype: int64

# %%
# all powerPS values greater than 1500 are assumed to be invalid for cars up to 200,000 price
df["powerPS"].sort_values(ascending=True).head(n=20)
df[df["powerPS"] > 1500].count()
# Out:
# index                  145
# dateCrawled            145
# name                   145
# price                  145
# abtest                 145
# vehicleType            126
# yearOfRegistration     145
# gearbox                141
# powerPS                145
# model                  141
# kilometer              145
# monthOfRegistration    145
# fuelType               123
# brand                  145
# notRepairedDamage       92
# dateCreated            145
# postalCode             145
# lastSeen               145
# dtype: int64

# %%
df_valid_powerPS = df[df['powerPS'] <= 1500]
nrows,ncols = 1,1
fig, axs = plt.subplots(nrows, ncols, figsize=(20,10))

sns.histplot(df_valid_powerPS['powerPS'], kde=True)
#sns.histplot(df['yearOfRegistration'], kde=True)
axs.set_title(f"Distribution of powerPS")
# Out:
# Text(0.5, 1.0, 'Distribution of powerPS')

# %%
numerical_features = ['yearOfRegistration', 'powerPS', 'kilometer', 'postalCode']
for feature in numerical_features:
    print(f"{feature} skewness:", df[feature].skew())
    print("="*50)
    
for feature in numerical_features:
    print(f"\nNormality tests for {feature}\n" + "="*50)
    results = run_normality_tests(df[feature])
    for test, result in results.items():
        print(f"{test}: {result}")
# Out:
# yearOfRegistration skewness: 93.77642024167571
# ==================================================
# powerPS skewness: 61.29150508721013
# ==================================================
# kilometer skewness: -1.3178216164954029
# ==================================================
# postalCode skewness: 0.02267863070850571
# ==================================================
#
# Normality tests for yearOfRegistration
# ==================================================
# Anderson-Darling Test: {'Statistic': 86258.64867950621, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.41983830884173523, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 1118898.000310177, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 1164911791940.7095, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.4198384457450258, 'p-value': 0.0009999999999998899, 'Normal': False}
#
# Normality tests for powerPS
# ==================================================
# Anderson-Darling Test: {'Statistic': 44704.8295964764, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.26127999870421587, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 971676.3537862157, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 277575405765.152, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.2612802543277402, 'p-value': 0.0009999999999998899, 'Normal': False}
#
# Normality tests for kilometer
# ==================================================
# Anderson-Darling Test: {'Statistic': 36834.3892526913, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.3521136257321933, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 52383.33952677126, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 86207.21564876361, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.3521132554749409, 'p-value': 0.0009999999999998899, 'Normal': False}
#
# Normality tests for postalCode
# ==================================================
# Anderson-Darling Test: {'Statistic': 1640.0970366644906, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.04930865798346218, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 61381.147045767546, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 11685.085841481668, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.04930824445396731, 'p-value': 0.0009999999999998899, 'Normal': False}

# %%
df_tmp = df.copy()
df_tmp = df_tmp[(df_tmp['yearOfRegistration'] >= 1920) & (df_tmp['yearOfRegistration'] <= 2025)]
df_tmp = df_tmp[df_tmp['powerPS'] <= 1500]

numerical_features = ['yearOfRegistration', 'powerPS', 'kilometer', 'postalCode']
for feature in numerical_features:
    print(f"{feature} skewness:", df_tmp[feature].skew())
    print("="*50)
    
for feature in numerical_features:
    print(f"\nNormality tests for {feature}\n" + "="*50)
    results = run_normality_tests(df_tmp[feature])
    for test, result in results.items():
        print(f"{test}: {result}")
# Out:
# yearOfRegistration skewness: -1.6622249982353725
# ==================================================
# powerPS skewness: 1.8975890456475286
# ==================================================
# kilometer skewness: -1.3178486057657628
# ==================================================
# postalCode skewness: 0.022541800323230027
# ==================================================
#
# Normality tests for yearOfRegistration
# ==================================================
# Anderson-Darling Test: {'Statistic': 3451.539508797112, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.09232162710674618, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 112277.97273597145, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 925344.895135896, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.09232201731745693, 'p-value': 0.0009999999999998899, 'Normal': False}
#
# Normality tests for powerPS
# ==================================================
# Anderson-Darling Test: {'Statistic': 3803.024210586387, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.10227377657049441, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 145535.94982236295, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 3781475.8809971693, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.10227400444105117, 'p-value': 0.0009999999999998899, 'Normal': False}
#
# Normality tests for kilometer
# ==================================================
# Anderson-Darling Test: {'Statistic': 36817.83772050374, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.35221028061777554, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 52343.87392170233, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 86143.46410272217, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.35220991008907426, 'p-value': 0.0009999999999998899, 'Normal': False}
#
# Normality tests for postalCode
# ==================================================
# Anderson-Darling Test: {'Statistic': 1638.819849563588, 'Critical Values': array([0.576, 0.656, 0.787, 0.918, 1.092]), 'Significance Levels': array([15. , 10. ,  5. ,  2.5,  1. ]), 'Normal': False}
# Kolmogorov-Smirnov Test: {'Statistic': 0.0493067206179415, 'p-value': 0.0, 'Normal': False}
# D’Agostino and Pearson’s Test: {'Statistic': 61336.8587372361, 'p-value': 0.0, 'Normal': False}
# Jarque-Bera Test: {'Statistic': 11675.898919809053, 'p-value': 0.0, 'Normal': False}
# Lilliefors Test: {'Statistic': 0.0493063067471774, 'p-value': 0.0009999999999998899, 'Normal': False}

# %% [markdown]
# ### Observations:
# * ALL numerical features except postalCode are skewed
# * NO numerical feature follows normal distribution
